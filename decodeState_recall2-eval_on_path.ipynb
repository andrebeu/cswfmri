# %%
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt

import sklearn
import brainiak
import nilearn as nl
from nilearn import image, plotting, input_data

from scipy.spatial import distance
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
pd.options.display.max_rows = 200

# %% [markdown]
# # load dataframes with timing and order information

# %%
view_df = pd.read_csv('deriv/view_df.csv',index_col=0)
view_df.iloc[:200]
# Out:
#       sub_num  vid_str  wed_num  onset_TR state  len_TRs  offset_TR schema  \
# 1428       25  vid1a_q        0        12    1b       17         29      S
# 1716       29  vid1a_q        0        12    1b       17         29      S
# 276         6  vid1a_q        0        12    1b       17         29      S
# 564        10  vid1a_q        0        12    1b       17         29      S
# 2220       36  vid1a_q        0        12    1b       17         29      S
# 2364       38  vid1a_q        0        12    1b       17         29      S
# 420         8  vid1a_q        0        12    1b       17         29      S
# 1284       23  vid1a_q        0        12    1b       17         29      S
# 1644       28  vid1a_q        0        12    1b       17         29      S
# 708        12  vid1a_q        0        12    1b       17         29      S
# 132         4  vid1a_q        0        12    1b       17         29      S
# 1212       22  vid1a_q        0        12    1b       17         29      S
# 1932       32  vid1a_q        0        12    1b       17         29      S
# 1068       18  vid1a_q        0        12    1b       17         29      S
# 2724       43  vid1a_q        0        12    1b       17         29      S
# 780        13  vid1a_q        0        12    1b       17         29      S
# 1860       31  vid1a_q        0        12    1b       17         29      S
# 1140       19  vid1a_q        0        12    1b       17         29      S
# 636        11  vid1a_q        0        12    1b       17         29      S
# 996        17  vid1a_q        0        12    1b       17         29      S
# 2580       41  vid1a_q        0        12    1b       17         29      S
# 2292       37  vid1a_q        0        12    1b       17         29    NaN
# 2796       44  vid1a_q        0        12    1b       17         29      S
# 492         9  vid1a_q        0        12    1b       17         29      S
# 1572       27  vid1a_q        0        12    1b       17         29      S
# 60          3  vid1a_q        0        12    1b       17         29      S
# 2148       35  vid1a_q        0        12    1b       17         29      S
# 924        15  vid1a_q        0        12    1b       17         29      S
# 204         5  vid1a_q        0        12    1b       17         29      S
# 2004       33  vid1a_q        0        12    1b       17         29      S
# 1788       30  vid1a_q        0        12    1b       17         29      S
# 2436       39  vid1a_q        0        12    1b       17         29    NaN
# 348         7  vid1a_q        0        13    1b       17         30      S
# 852        14  vid1a_q        0        13    1b       17         30      S
# 2652       42  vid1a_q        0        13    1b       17         30      S
# 2508       40  vid1a_q        0        13    1b       17         30      S
# 1356       24  vid1a_q        0        13    1b       17         30      S
# 1500       26  vid1a_q        0        13    1b       17         30      S
# 2076       34  vid1a_q        0        13    1b       17         30      S
# 1214       22  vid1b_q        0        29    1b        6         35      S
# 2438       39  vid1b_q        0        29    1b        6         35    NaN
# 1790       30  vid1b_q        0        29    1b        6         35      S
# 494         9  vid1b_q        0        29    1b        6         35      S
# 638        11  vid1b_q        0        29    1b        6         35      S
# 2726       43  vid1b_q        0        29    1b        6         35      S
# 1142       19  vid1b_q        0        29    1b        6         35      S
# 854        14  vid1b_q        0        29    1b        6         35      S
# 2654       42  vid1b_q        0        29    1b        6         35      S
# 2150       35  vid1b_q        0        29    1b        6         35      S
# 206         5  vid1b_q        0        29    1b        6         35      S
# 2078       34  vid1b_q        0        29    1b        6         35      S
# 926        15  vid1b_q        0        29    1b        6         35      S
# 2582       41  vid1b_q        0        29    1b        6         35      S
# 782        13  vid1b_q        0        29    1b        6         35      S
# 2006       33  vid1b_q        0        29    1b        6         35      S
# 566        10  vid1b_q        0        29    1b        6         35      S
# 278         6  vid1b_q        0        29    1b        6         35      S
# 2366       38  vid1b_q        0        29    1b        6         35      S
# 134         4  vid1b_q        0        29    1b        6         35      S
# 1934       32  vid1b_q        0        29    1b        6         35      S
# 1070       18  vid1b_q        0        29    1b        6         35      S
# 1862       31  vid1b_q        0        29    1b        6         35      S
# 998        17  vid1b_q        0        29    1b        6         35      S
# 1286       23  vid1b_q        0        29    1b        6         35      S
# 2294       37  vid1b_q        0        29    1b        6         35    NaN
# 1646       28  vid1b_q        0        29    1b        6         35      S
# 2510       40  vid1b_q        0        29    1b        6         35      S
# 710        12  vid1b_q        0        29    1b        6         35      S
# 1358       24  vid1b_q        0        29    1b        6         35      S
# 2798       44  vid1b_q        0        29    1b        6         35      S
# 422         8  vid1b_q        0        29    1b        6         35      S
# 350         7  vid1b_q        0        29    1b        6         35      S
# 1718       29  vid1b_q        0        29    1b        6         35      S
# 1502       26  vid1b_q        0        29    1b        6         35      S
# 1574       27  vid1b_q        0        29    1b        6         35      S
# 1430       25  vid1b_q        0        29    1b        6         35      S
# 2222       36  vid1b_q        0        29    1b        6         35      S
# 62          3  vid1b_q        0        29    1b        6         35      S
# 280         6   vid2_q        0        35    2b       11         46      S
# 712        12   vid2_q        0        35    2a       11         46      S
# 2152       35   vid2_q        0        35    2a       11         46      S
# 2584       41   vid2_q        0        35    2a       11         46      S
# 1864       31   vid2_q        0        35    2b       11         46      S
# 2800       44   vid2_q        0        35    2a       11         46      S
# 1576       27   vid2_q        0        35    2a       11         46      S
# 2008       33   vid2_q        0        35    2b       11         46      S
# 2080       34   vid2_q        0        35    2a       11         46      S
# 208         5   vid2_q        0        35    2b       11         46      S
# 352         7   vid2_q        0        35    2a       11         46      S
# 2368       38   vid2_q        0        35    2b       11         46      S
# 1504       26   vid2_q        0        35    2b       11         46      S
# 1648       28   vid2_q        0        35    2b       11         46      S
# 64          3   vid2_q        0        35    2b       11         46      S
# 1936       32   vid2_q        0        35    2a       11         46      S
# 1144       19   vid2_q        0        35    2b       11         46      S
# 136         4   vid2_q        0        35    2a       11         46      S
# 1000       17   vid2_q        0        35    2b       11         46      S
# 2512       40   vid2_q        0        35    2a       11         46      S
# 928        15   vid2_q        0        35    2a       11         46      S
# 1432       25   vid2_q        0        35    2a       11         46      S
# 784        13   vid2_q        0        35    2b       11         46      S
# 1072       18   vid2_q        0        35    2b       11         46      S
# 2656       42   vid2_q        0        35    2a       11         46      S
# 568        10   vid2_q        0        35    2b       11         46      S
# 424         8   vid2_q        0        35    2b       11         46      S
# 2224       36   vid2_q        0        35    2b       11         46      S
# 496         9   vid2_q        0        35    2b       11         46      S
# 640        11   vid2_q        0        35    2b       11         46      S
# 1216       22   vid2_q        0        35    2b       11         46      S
# 2728       43   vid2_q        0        35    2a       11         46      S
# 2296       37   vid2_q        0        35    2a       11         46    NaN
# 1288       23   vid2_q        0        35    2a       11         46      S
# 1360       24   vid2_q        0        35    2a       11         46      S
# 856        14   vid2_q        0        35    2a       11         46      S
# 1792       30   vid2_q        0        35    2a       11         46      S
# 2440       39   vid2_q        0        35    2b       11         46    NaN
# 1720       29   vid2_q        0        35    2b       11         46      S
# 354         7   vid3_q        0        49    3b       15         64      S
# 2442       39   vid3_q        0        49    3a       15         64    NaN
# 426         8   vid3_q        0        49    3a       15         64      S
# 1434       25   vid3_q        0        49    3b       15         64      S
# 930        15   vid3_q        0        49    3b       15         64      S
# 858        14   vid3_q        0        49    3b       15         64      S
# 1002       17   vid3_q        0        49    3a       15         64      S
# 210         5   vid3_q        0        49    3a       15         64      S
# 138         4   vid3_q        0        49    3b       15         64      S
# 2226       36   vid3_q        0        49    3a       15         64      S
# 642        11   vid3_q        0        49    3a       15         64      S
# 1578       27   vid3_q        0        49    3b       15         64      S
# 2010       33   vid3_q        0        49    3a       15         64      S
# 2298       37   vid3_q        0        49    3b       15         64    NaN
# 570        10   vid3_q        0        49    3a       15         64      S
# 1290       23   vid3_q        0        49    3b       15         64      S
# 66          3   vid3_q        0        49    3a       15         64      S
# 2514       40   vid3_q        0        49    3b       15         64      S
# 1722       29   vid3_q        0        49    3a       15         64      S
# 1866       31   vid3_q        0        49    3a       15         64      S
# 2154       35   vid3_q        0        49    3b       15         64      S
# 2586       41   vid3_q        0        49    3b       15         64      S
# 714        12   vid3_q        0        49    3b       15         64      S
# 1146       19   vid3_q        0        49    3a       15         64      S
# 1938       32   vid3_q        0        49    3b       15         64      S
# 2658       42   vid3_q        0        49    3b       15         64      S
# 2370       38   vid3_q        0        49    3a       15         64      S
# 1506       26   vid3_q        0        49    3a       15         64      S
# 282         6   vid3_q        0        49    3a       15         64      S
# 498         9   vid3_q        0        49    3a       15         64      S
# 2802       44   vid3_q        0        49    3b       15         64      S
# 1074       18   vid3_q        0        49    3a       15         64      S
# 1794       30   vid3_q        0        49    3b       15         64      S
# 786        13   vid3_q        0        49    3a       15         64      S
# 1650       28   vid3_q        0        49    3a       15         64      S
# 1218       22   vid3_q        0        49    3a       15         64      S
# 2082       34   vid3_q        0        49    3b       15         64      S
# 1362       24   vid3_q        0        49    3b       15         64      S
# 2730       43   vid3_q        0        49    3b       15         64      S
# 860        14   vid4_q        0        67    4a       16         83      S
# 2804       44   vid4_q        0        67    4a       16         83      S
# 2300       37   vid4_q        0        67    4a       16         83    NaN
# 2660       42   vid4_q        0        67    4a       16         83      S
# 788        13   vid4_q        0        67    4b       16         83      S
# 932        15   vid4_q        0        67    4a       16         83      S
# 2588       41   vid4_q        0        67    4a       16         83      S
# 1508       26   vid4_q        0        67    4b       16         83      S
# 572        10   vid4_q        0        67    4b       16         83      S
# 2084       34   vid4_q        0        67    4a       16         83      S
# 1292       23   vid4_q        0        67    4a       16         83      S
# 1580       27   vid4_q        0        67    4a       16         83      S
# 68          3   vid4_q        0        67    4b       16         83      S
# 644        11   vid4_q        0        67    4b       16         83      S
# 2444       39   vid4_q        0        67    4b       16         83    NaN
# 428         8   vid4_q        0        67    4b       16         83      S
# 1724       29   vid4_q        0        67    4b       16         83      S
# 1220       22   vid4_q        0        67    4b       16         83      S
# 2732       43   vid4_q        0        67    4a       16         83      S
# 1796       30   vid4_q        0        67    4a       16         83      S
# 500         9   vid4_q        0        67    4b       16         83      S
# 2156       35   vid4_q        0        67    4a       16         83      S
# 1364       24   vid4_q        0        67    4a       16         83      S
# 2012       33   vid4_q        0        67    4b       16         83      S
# 1148       19   vid4_q        0        67    4b       16         83      S
# 716        12   vid4_q        0        67    4a       16         83      S
# 2372       38   vid4_q        0        67    4b       16         83      S
# 2228       36   vid4_q        0        67    4b       16         83      S
# 284         6   vid4_q        0        67    4b       16         83      S
# 1076       18   vid4_q        0        67    4b       16         83      S
# 2516       40   vid4_q        0        67    4a       16         83      S
# 356         7   vid4_q        0        67    4a       16         83      S
# 1652       28   vid4_q        0        67    4b       16         83      S
# 1940       32   vid4_q        0        67    4a       16         83      S
# 1868       31   vid4_q        0        67    4b       16         83      S
# 212         5   vid4_q        0        67    4b       16         83      S
# 1004       17   vid4_q        0        67    4b       16         83      S
# 140         4   vid4_q        0        67    4a       16         83      S
# 1436       25   vid4_q        0        67    4a       16         83      S
# 214         5   vid5_q        0        83     5        7         90      S
# 790        13   vid5_q        0        83     5        7         90      S
# 718        12   vid5_q        0        83     5        7         90      S
# 2158       35   vid5_q        0        83     5        7         90      S
# 646        11   vid5_q        0        83     5        7         90      S
#
#       wed_id
# 1428    20.0
# 1716    22.0
# 276      6.0
# 564     17.0
# 2220     2.0
# 2364    23.0
# 420      1.0
# 1284    28.0
# 1644    22.0
# 708     34.0
# 132     23.0
# 1212    28.0
# 1932    29.0
# 1068    29.0
# 2724     2.0
# 780     23.0
# 1860    17.0
# 1140    20.0
# 636     34.0
# 996     22.0
# 2580    17.0
# 2292     NaN
# 2796    22.0
# 492      6.0
# 1572    22.0
# 60      20.0
# 2148     1.0
# 924     34.0
# 204     23.0
# 2004    23.0
# 1788    38.0
# 2436     NaN
# 348     23.0
# 852     22.0
# 2652    20.0
# 2508     6.0
# 1356    22.0
# 1500    22.0
# 2076    28.0
# 1214    28.0
# 2438     NaN
# 1790    38.0
# 494      6.0
# 638     34.0
# 2726     2.0
# 1142    20.0
# 854     22.0
# 2654    20.0
# 2150     1.0
# 206     23.0
# 2078    28.0
# 926     34.0
# 2582    17.0
# 782     23.0
# 2006    23.0
# 566     17.0
# 278      6.0
# 2366    23.0
# 134     23.0
# 1934    29.0
# 1070    29.0
# 1862    17.0
# 998     22.0
# 1286    28.0
# 2294     NaN
# 1646    22.0
# 2510     6.0
# 710     34.0
# 1358    22.0
# 2798    22.0
# 422      1.0
# 350     23.0
# 1718    22.0
# 1502    22.0
# 1574    22.0
# 1430    20.0
# 2222     2.0
# 62      20.0
# 280      6.0
# 712     34.0
# 2152     1.0
# 2584    17.0
# 1864    17.0
# 2800    22.0
# 1576    22.0
# 2008    23.0
# 2080    28.0
# 208     23.0
# 352     23.0
# 2368    23.0
# 1504    22.0
# 1648    22.0
# 64      20.0
# 1936    29.0
# 1144    20.0
# 136     23.0
# 1000    22.0
# 2512     6.0
# 928     34.0
# 1432    20.0
# 784     23.0
# 1072    29.0
# 2656    20.0
# 568     17.0
# 424      1.0
# 2224     2.0
# 496      6.0
# 640     34.0
# 1216    28.0
# 2728     2.0
# 2296     NaN
# 1288    28.0
# 1360    22.0
# 856     22.0
# 1792    38.0
# 2440     NaN
# 1720    22.0
# 354     23.0
# 2442     NaN
# 426      1.0
# 1434    20.0
# 930     34.0
# 858     22.0
# 1002    22.0
# 210     23.0
# 138     23.0
# 2226     2.0
# 642     34.0
# 1578    22.0
# 2010    23.0
# 2298     NaN
# 570     17.0
# 1290    28.0
# 66      20.0
# 2514     6.0
# 1722    22.0
# 1866    17.0
# 2154     1.0
# 2586    17.0
# 714     34.0
# 1146    20.0
# 1938    29.0
# 2658    20.0
# 2370    23.0
# 1506    22.0
# 282      6.0
# 498      6.0
# 2802    22.0
# 1074    29.0
# 1794    38.0
# 786     23.0
# 1650    22.0
# 1218    28.0
# 2082    28.0
# 1362    22.0
# 2730     2.0
# 860     22.0
# 2804    22.0
# 2300     NaN
# 2660    20.0
# 788     23.0
# 932     34.0
# 2588    17.0
# 1508    22.0
# 572     17.0
# 2084    28.0
# 1292    28.0
# 1580    22.0
# 68      20.0
# 644     34.0
# 2444     NaN
# 428      1.0
# 1724    22.0
# 1220    28.0
# 2732     2.0
# 1796    38.0
# 500      6.0
# 2156     1.0
# 1364    22.0
# 2012    23.0
# 1148    20.0
# 716     34.0
# 2372    23.0
# 2228     2.0
# 284      6.0
# 1076    29.0
# 2516     6.0
# 356     23.0
# 1652    22.0
# 1940    29.0
# 1868    17.0
# 212     23.0
# 1004    22.0
# 140     23.0
# 1436    20.0
# 214     23.0
# 790     23.0
# 718     34.0
# 2158     1.0
# 646     34.0

# %%
recall_df = pd.read_csv('deriv/recall_df.csv',index_col=0)
recall_df
# Out:
#        sub_num  wed_id  onsetTR  offsetTR  recall   TR schema path
# 0            3      22        0        57       0    0      N   Nb
# 1            3      22        0        57       0    1      N   Nb
# 2            3      22        0        57       0    2      N   Nb
# 3            3      22        0        57       0    3      N   Nb
# 4            3      22        0        57       0    4      N   Nb
# ...        ...     ...      ...       ...     ...  ...    ...  ...
# 16248       44      17      312       337       9  332      N   Nb
# 16249       44      17      312       337       0  333      N   Nb
# 16250       44      17      312       337       0  334      N   Nb
# 16251       44      17      312       337       0  335      N   Nb
# 16252       44      17      312       337       0  336      N   Nb
#
# [16253 rows x 8 columns]

# %% [markdown]
# # form training and testing datasets

# %% [markdown]
# ### classifier training

# %%
## dict mapping (layer,state):recall_transcript_code
recall_label_D = {
  (2,'a'):3,
  (2,'b'):4,
  (3,'a'):5,
  (3,'b'):6,
  (4,'a'):7,
  (4,'b'):8
}

""" 
when constructing training data, 
I assume that 'a' states are positive
the first two are paths with 'a' states
the last two are paths with 'b' states
"""
layer2_paths_D = {
  2: ['Na','Sa','Nb','Sb'],
  3: ['Na','Sb','Nb','Sa'],
  4: ['Na','Sa','Nb','Sb']
}

# %%
def get_training_info(sub_num,layer_num):
  # find df rows corresponding to sub/layer
  layer_bool = view_df.state.str[0]==str(layer_num)
  sub_bool = (view_df.sub_num == sub_num)
  sub_layer_view_df = view_df[sub_bool & layer_bool]
  # extract TRs and labels 
  TR_L = []
  ytarget_L = []
  for idx,row in sub_layer_view_df.iterrows():
    TRs = np.arange(row.onset_TR,row.offset_TR)
    TR_L.extend(TRs)
    ytarget_L.extend(np.repeat(row.state[1]=='a',len(TRs)))
  return np.array(TR_L),np.array(ytarget_L)

# %%
def get_test_info(sub_num,layer_num):
  sub_bool = (recall_df.sub_num==sub_num)
  sub_recall_df = recall_df[sub_bool]
  XTRs = []
  ylabels = []
  for pos_path in layer2_paths_D[layer_num][:2]: 
    pos_path_TRs = sub_recall_df[sub_recall_df.path == pos_path].TR.values
    XTRs.extend(pos_path_TRs)
    ylabels.extend(np.repeat(True,len(pos_path_TRs)))
  for neg_path in layer2_paths_D[layer_num][2:]: 
    neg_path_TRs = sub_recall_df[sub_recall_df.path == neg_path].TR.values
    XTRs.extend(neg_path_TRs)
    ylabels.extend(np.repeat(False,len(neg_path_TRs)))
  return np.array(XTRs),np.array(ylabels)

# %% [markdown]
# # main

# %%
def load_sub_roi(sub_num,roi_name,task):
  fpath = "sub-%i_task-%s_roi-%s.npy" %(sub_num,task,roi_name)
  return np.load('data/fmri/masked/'+fpath)

# %%
ROI_NAME_L = [
  'SnPM_filtered_FDR',
  'rglasser_AT_net',
  'rglasser_MP_net',
  'rglasser_MTN_net',
  'rglasser_PM_net',
  'rhippocampusAAL', 
]

# %%
def get_classifier_data(sub_num,roi_name,layer_num):
  """ 
  given info, returns train and test data
  """
  # load fmri data; 
  try: # check that fmri files exist
    act_view = load_sub_roi(sub_num,roi_name,'videos')
    act_recall = load_sub_roi(sub_num,roi_name,'recall2')
    assert len(act_view)
    assert len(act_recall)
  except:
    print('err loading roi data')
    return None
  
  ## train data
  try: # train
    XTR_train,ylabel_train = get_training_info(sub_num,layer_num)
    Xtrain = act_view[XTR_train,:]
  except:
    print('err getting classifier train data')
    return None
  
  ## test data
  try: 
    XTR_test,ylabel_test = get_test_info(sub_num,layer_num)  
    Xtest = act_recall[XTR_test,:]
  except:
    print('err getting classifier test data')
    return None
  # check if recall data exists
  try:
    assert len(Xtest)
  except:
    print('no recall data')
    return None
  
  return Xtrain,ylabel_train,Xtest,ylabel_test

# %%
""" 
train and test classifier
"""

L = []

# data level vars
for roi_name,sub_num in itertools.product(ROI_NAME_L,np.arange(45)):
  # analysis level vars
  for layer_num in np.arange(2,5):
    print('roi',roi_name,'sub',sub_num,'layer',layer_num)
    
    ## LOAD DATA
    data = get_classifier_data(sub_num,roi_name, layer_num)
    if data == None: continue
    Xtrain,Ytrain,Xtest,Ytest = data
     
    ## normalize
    scaler = StandardScaler()
    Xtrain = scaler.fit_transform(Xtrain)
    Xtest = scaler.transform(Xtest)
    
    ## fit classifier
    clf = sklearn.linear_model.LogisticRegression(solver='liblinear',C=1.00)
    clf.fit(Xtrain,Ytrain)
    
    # eval classifier
    yhat = clf.predict_proba(Xtrain)
    score = clf.score(Xtest,Ytest)
    
    ## record data
    D = {}
    D['sub_num']=sub_num
    D['roi']=roi_name
    D['layer']=layer_num
    D['num_test_samples']=len(Ytest)
    D['score']=score  
    L.append(D)

## 
results = pd.DataFrame(L)
# Out:
# roi SnPM_filtered_FDR sub 0 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 0 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 0 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 1 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 1 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 1 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 2 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 2 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 2 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 3 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 3 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 3 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 4 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 4 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 4 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 5 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 5 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 5 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 6 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 6 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 6 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 7 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 7 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 7 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 8 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 8 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 8 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 9 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 9 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 9 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 10 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 10 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 10 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 11 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 11 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 11 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 12 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 12 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 12 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 13 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 13 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 13 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 14 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 14 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 14 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 15 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 15 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 15 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 16 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 16 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 16 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 17 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 17 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 17 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 18 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 18 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 18 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 19 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 19 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 19 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 20 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 20 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 20 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 21 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 21 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 21 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 22 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 22 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 22 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 23 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 23 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 23 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 24 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 24 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 24 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 25 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 25 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 25 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 26 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 26 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 26 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 27 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 27 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 27 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 28 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 28 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 28 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 29 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 29 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 29 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 30 layer 2
# roi SnPM_filtered_FDR sub 30 layer 3
# roi SnPM_filtered_FDR sub 30 layer 4
# roi SnPM_filtered_FDR sub 31 layer 2
# roi SnPM_filtered_FDR sub 31 layer 3
# roi SnPM_filtered_FDR sub 31 layer 4
# roi SnPM_filtered_FDR sub 32 layer 2
# roi SnPM_filtered_FDR sub 32 layer 3
# roi SnPM_filtered_FDR sub 32 layer 4
# roi SnPM_filtered_FDR sub 33 layer 2
# roi SnPM_filtered_FDR sub 33 layer 3
# roi SnPM_filtered_FDR sub 33 layer 4
# roi SnPM_filtered_FDR sub 34 layer 2
# roi SnPM_filtered_FDR sub 34 layer 3
# roi SnPM_filtered_FDR sub 34 layer 4
# roi SnPM_filtered_FDR sub 35 layer 2
# roi SnPM_filtered_FDR sub 35 layer 3
# roi SnPM_filtered_FDR sub 35 layer 4
# roi SnPM_filtered_FDR sub 36 layer 2
# roi SnPM_filtered_FDR sub 36 layer 3
# roi SnPM_filtered_FDR sub 36 layer 4
# roi SnPM_filtered_FDR sub 37 layer 2
# err getting classifier test data
# roi SnPM_filtered_FDR sub 37 layer 3
# err getting classifier test data
# roi SnPM_filtered_FDR sub 37 layer 4
# err getting classifier test data
# roi SnPM_filtered_FDR sub 38 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 38 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 38 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 39 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 39 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 39 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 40 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 40 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 40 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 41 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 41 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 41 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 42 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 42 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 42 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 43 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 43 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 43 layer 4
# err loading roi data
# roi SnPM_filtered_FDR sub 44 layer 2
# err loading roi data
# roi SnPM_filtered_FDR sub 44 layer 3
# err loading roi data
# roi SnPM_filtered_FDR sub 44 layer 4
# err loading roi data
# roi rglasser_AT_net sub 0 layer 2
# err loading roi data
# roi rglasser_AT_net sub 0 layer 3
# err loading roi data
# roi rglasser_AT_net sub 0 layer 4
# err loading roi data
# roi rglasser_AT_net sub 1 layer 2
# err loading roi data
# roi rglasser_AT_net sub 1 layer 3
# err loading roi data
# roi rglasser_AT_net sub 1 layer 4
# err loading roi data
# roi rglasser_AT_net sub 2 layer 2
# err loading roi data
# roi rglasser_AT_net sub 2 layer 3
# err loading roi data
# roi rglasser_AT_net sub 2 layer 4
# err loading roi data
# roi rglasser_AT_net sub 3 layer 2
# err loading roi data
# roi rglasser_AT_net sub 3 layer 3
# err loading roi data
# roi rglasser_AT_net sub 3 layer 4
# err loading roi data
# roi rglasser_AT_net sub 4 layer 2
# err loading roi data
# roi rglasser_AT_net sub 4 layer 3
# err loading roi data
# roi rglasser_AT_net sub 4 layer 4
# err loading roi data
# roi rglasser_AT_net sub 5 layer 2
# err loading roi data
# roi rglasser_AT_net sub 5 layer 3
# err loading roi data
# roi rglasser_AT_net sub 5 layer 4
# err loading roi data
# roi rglasser_AT_net sub 6 layer 2
# err loading roi data
# roi rglasser_AT_net sub 6 layer 3
# err loading roi data
# roi rglasser_AT_net sub 6 layer 4
# err loading roi data
# roi rglasser_AT_net sub 7 layer 2
# err loading roi data
# roi rglasser_AT_net sub 7 layer 3
# err loading roi data
# roi rglasser_AT_net sub 7 layer 4
# err loading roi data
# roi rglasser_AT_net sub 8 layer 2
# err loading roi data
# roi rglasser_AT_net sub 8 layer 3
# err loading roi data
# roi rglasser_AT_net sub 8 layer 4
# err loading roi data
# roi rglasser_AT_net sub 9 layer 2
# err loading roi data
# roi rglasser_AT_net sub 9 layer 3
# err loading roi data
# roi rglasser_AT_net sub 9 layer 4
# err loading roi data
# roi rglasser_AT_net sub 10 layer 2
# err loading roi data
# roi rglasser_AT_net sub 10 layer 3
# err loading roi data
# roi rglasser_AT_net sub 10 layer 4
# err loading roi data
# roi rglasser_AT_net sub 11 layer 2
# err loading roi data
# roi rglasser_AT_net sub 11 layer 3
# err loading roi data
# roi rglasser_AT_net sub 11 layer 4
# err loading roi data
# roi rglasser_AT_net sub 12 layer 2
# err loading roi data
# roi rglasser_AT_net sub 12 layer 3
# err loading roi data
# roi rglasser_AT_net sub 12 layer 4
# err loading roi data
# roi rglasser_AT_net sub 13 layer 2
# err loading roi data
# roi rglasser_AT_net sub 13 layer 3
# err loading roi data
# roi rglasser_AT_net sub 13 layer 4
# err loading roi data
# roi rglasser_AT_net sub 14 layer 2
# err loading roi data
# roi rglasser_AT_net sub 14 layer 3
# err loading roi data
# roi rglasser_AT_net sub 14 layer 4
# err loading roi data
# roi rglasser_AT_net sub 15 layer 2
# err loading roi data
# roi rglasser_AT_net sub 15 layer 3
# err loading roi data
# roi rglasser_AT_net sub 15 layer 4
# err loading roi data
# roi rglasser_AT_net sub 16 layer 2
# err loading roi data
# roi rglasser_AT_net sub 16 layer 3
# err loading roi data
# roi rglasser_AT_net sub 16 layer 4
# err loading roi data
# roi rglasser_AT_net sub 17 layer 2
# err loading roi data
# roi rglasser_AT_net sub 17 layer 3
# err loading roi data
# roi rglasser_AT_net sub 17 layer 4
# err loading roi data
# roi rglasser_AT_net sub 18 layer 2
# err loading roi data
# roi rglasser_AT_net sub 18 layer 3
# err loading roi data
# roi rglasser_AT_net sub 18 layer 4
# err loading roi data
# roi rglasser_AT_net sub 19 layer 2
# err loading roi data
# roi rglasser_AT_net sub 19 layer 3
# err loading roi data
# roi rglasser_AT_net sub 19 layer 4
# err loading roi data
# roi rglasser_AT_net sub 20 layer 2
# err loading roi data
# roi rglasser_AT_net sub 20 layer 3
# err loading roi data
# roi rglasser_AT_net sub 20 layer 4
# err loading roi data
# roi rglasser_AT_net sub 21 layer 2
# err loading roi data
# roi rglasser_AT_net sub 21 layer 3
# err loading roi data
# roi rglasser_AT_net sub 21 layer 4
# err loading roi data
# roi rglasser_AT_net sub 22 layer 2
# err loading roi data
# roi rglasser_AT_net sub 22 layer 3
# err loading roi data
# roi rglasser_AT_net sub 22 layer 4
# err loading roi data
# roi rglasser_AT_net sub 23 layer 2
# err loading roi data
# roi rglasser_AT_net sub 23 layer 3
# err loading roi data
# roi rglasser_AT_net sub 23 layer 4
# err loading roi data
# roi rglasser_AT_net sub 24 layer 2
# err loading roi data
# roi rglasser_AT_net sub 24 layer 3
# err loading roi data
# roi rglasser_AT_net sub 24 layer 4
# err loading roi data
# roi rglasser_AT_net sub 25 layer 2
# err loading roi data
# roi rglasser_AT_net sub 25 layer 3
# err loading roi data
# roi rglasser_AT_net sub 25 layer 4
# err loading roi data
# roi rglasser_AT_net sub 26 layer 2
# err loading roi data
# roi rglasser_AT_net sub 26 layer 3
# err loading roi data
# roi rglasser_AT_net sub 26 layer 4
# err loading roi data
# roi rglasser_AT_net sub 27 layer 2
# err loading roi data
# roi rglasser_AT_net sub 27 layer 3
# err loading roi data
# roi rglasser_AT_net sub 27 layer 4
# err loading roi data
# roi rglasser_AT_net sub 28 layer 2
# err loading roi data
# roi rglasser_AT_net sub 28 layer 3
# err loading roi data
# roi rglasser_AT_net sub 28 layer 4
# err loading roi data
# roi rglasser_AT_net sub 29 layer 2
# err loading roi data
# roi rglasser_AT_net sub 29 layer 3
# err loading roi data
# roi rglasser_AT_net sub 29 layer 4
# err loading roi data
# roi rglasser_AT_net sub 30 layer 2
# roi rglasser_AT_net sub 30 layer 3
# roi rglasser_AT_net sub 30 layer 4
# roi rglasser_AT_net sub 31 layer 2
# roi rglasser_AT_net sub 31 layer 3
# roi rglasser_AT_net sub 31 layer 4
# roi rglasser_AT_net sub 32 layer 2
# roi rglasser_AT_net sub 32 layer 3
# roi rglasser_AT_net sub 32 layer 4
# roi rglasser_AT_net sub 33 layer 2
# roi rglasser_AT_net sub 33 layer 3
# roi rglasser_AT_net sub 33 layer 4
# roi rglasser_AT_net sub 34 layer 2
# roi rglasser_AT_net sub 34 layer 3
# roi rglasser_AT_net sub 34 layer 4
# roi rglasser_AT_net sub 35 layer 2
# roi rglasser_AT_net sub 35 layer 3
# roi rglasser_AT_net sub 35 layer 4
# roi rglasser_AT_net sub 36 layer 2
# roi rglasser_AT_net sub 36 layer 3
# roi rglasser_AT_net sub 36 layer 4
# roi rglasser_AT_net sub 37 layer 2
# err getting classifier test data
# roi rglasser_AT_net sub 37 layer 3
# err getting classifier test data
# roi rglasser_AT_net sub 37 layer 4
# err getting classifier test data
# roi rglasser_AT_net sub 38 layer 2
# roi rglasser_AT_net sub 38 layer 3
# roi rglasser_AT_net sub 38 layer 4
# roi rglasser_AT_net sub 39 layer 2
# err loading roi data
# roi rglasser_AT_net sub 39 layer 3
# err loading roi data
# roi rglasser_AT_net sub 39 layer 4
# err loading roi data
# roi rglasser_AT_net sub 40 layer 2
# err loading roi data
# roi rglasser_AT_net sub 40 layer 3
# err loading roi data
# roi rglasser_AT_net sub 40 layer 4
# err loading roi data
# roi rglasser_AT_net sub 41 layer 2
# err loading roi data
# roi rglasser_AT_net sub 41 layer 3
# err loading roi data
# roi rglasser_AT_net sub 41 layer 4
# err loading roi data
# roi rglasser_AT_net sub 42 layer 2
# err loading roi data
# roi rglasser_AT_net sub 42 layer 3
# err loading roi data
# roi rglasser_AT_net sub 42 layer 4
# err loading roi data
# roi rglasser_AT_net sub 43 layer 2
# err loading roi data
# roi rglasser_AT_net sub 43 layer 3
# err loading roi data
# roi rglasser_AT_net sub 43 layer 4
# err loading roi data
# roi rglasser_AT_net sub 44 layer 2
# err loading roi data
# roi rglasser_AT_net sub 44 layer 3
# err loading roi data
# roi rglasser_AT_net sub 44 layer 4
# err loading roi data
# roi rglasser_MP_net sub 0 layer 2
# err loading roi data
# roi rglasser_MP_net sub 0 layer 3
# err loading roi data
# roi rglasser_MP_net sub 0 layer 4
# err loading roi data
# roi rglasser_MP_net sub 1 layer 2
# err loading roi data
# roi rglasser_MP_net sub 1 layer 3
# err loading roi data
# roi rglasser_MP_net sub 1 layer 4
# err loading roi data
# roi rglasser_MP_net sub 2 layer 2
# err loading roi data
# roi rglasser_MP_net sub 2 layer 3
# err loading roi data
# roi rglasser_MP_net sub 2 layer 4
# err loading roi data
# roi rglasser_MP_net sub 3 layer 2
# err loading roi data
# roi rglasser_MP_net sub 3 layer 3
# err loading roi data
# roi rglasser_MP_net sub 3 layer 4
# err loading roi data
# roi rglasser_MP_net sub 4 layer 2
# err loading roi data
# roi rglasser_MP_net sub 4 layer 3
# err loading roi data
# roi rglasser_MP_net sub 4 layer 4
# err loading roi data
# roi rglasser_MP_net sub 5 layer 2
# err loading roi data
# roi rglasser_MP_net sub 5 layer 3
# err loading roi data
# roi rglasser_MP_net sub 5 layer 4
# err loading roi data
# roi rglasser_MP_net sub 6 layer 2
# err loading roi data
# roi rglasser_MP_net sub 6 layer 3
# err loading roi data
# roi rglasser_MP_net sub 6 layer 4
# err loading roi data
# roi rglasser_MP_net sub 7 layer 2
# err loading roi data
# roi rglasser_MP_net sub 7 layer 3
# err loading roi data
# roi rglasser_MP_net sub 7 layer 4
# err loading roi data
# roi rglasser_MP_net sub 8 layer 2
# err loading roi data
# roi rglasser_MP_net sub 8 layer 3
# err loading roi data
# roi rglasser_MP_net sub 8 layer 4
# err loading roi data
# roi rglasser_MP_net sub 9 layer 2
# err loading roi data
# roi rglasser_MP_net sub 9 layer 3
# err loading roi data
# roi rglasser_MP_net sub 9 layer 4
# err loading roi data
# roi rglasser_MP_net sub 10 layer 2
# err loading roi data
# roi rglasser_MP_net sub 10 layer 3
# err loading roi data
# roi rglasser_MP_net sub 10 layer 4
# err loading roi data
# roi rglasser_MP_net sub 11 layer 2
# err loading roi data
# roi rglasser_MP_net sub 11 layer 3
# err loading roi data
# roi rglasser_MP_net sub 11 layer 4
# err loading roi data
# roi rglasser_MP_net sub 12 layer 2
# err loading roi data
# roi rglasser_MP_net sub 12 layer 3
# err loading roi data
# roi rglasser_MP_net sub 12 layer 4
# err loading roi data
# roi rglasser_MP_net sub 13 layer 2
# err loading roi data
# roi rglasser_MP_net sub 13 layer 3
# err loading roi data
# roi rglasser_MP_net sub 13 layer 4
# err loading roi data
# roi rglasser_MP_net sub 14 layer 2
# err loading roi data
# roi rglasser_MP_net sub 14 layer 3
# err loading roi data
# roi rglasser_MP_net sub 14 layer 4
# err loading roi data
# roi rglasser_MP_net sub 15 layer 2
# err loading roi data
# roi rglasser_MP_net sub 15 layer 3
# err loading roi data
# roi rglasser_MP_net sub 15 layer 4
# err loading roi data
# roi rglasser_MP_net sub 16 layer 2
# err loading roi data
# roi rglasser_MP_net sub 16 layer 3
# err loading roi data
# roi rglasser_MP_net sub 16 layer 4
# err loading roi data
# roi rglasser_MP_net sub 17 layer 2
# err loading roi data
# roi rglasser_MP_net sub 17 layer 3
# err loading roi data
# roi rglasser_MP_net sub 17 layer 4
# err loading roi data
# roi rglasser_MP_net sub 18 layer 2
# err loading roi data
# roi rglasser_MP_net sub 18 layer 3
# err loading roi data
# roi rglasser_MP_net sub 18 layer 4
# err loading roi data
# roi rglasser_MP_net sub 19 layer 2
# err loading roi data
# roi rglasser_MP_net sub 19 layer 3
# err loading roi data
# roi rglasser_MP_net sub 19 layer 4
# err loading roi data
# roi rglasser_MP_net sub 20 layer 2
# err loading roi data
# roi rglasser_MP_net sub 20 layer 3
# err loading roi data
# roi rglasser_MP_net sub 20 layer 4
# err loading roi data
# roi rglasser_MP_net sub 21 layer 2
# err loading roi data
# roi rglasser_MP_net sub 21 layer 3
# err loading roi data
# roi rglasser_MP_net sub 21 layer 4
# err loading roi data
# roi rglasser_MP_net sub 22 layer 2
# err loading roi data
# roi rglasser_MP_net sub 22 layer 3
# err loading roi data
# roi rglasser_MP_net sub 22 layer 4
# err loading roi data
# roi rglasser_MP_net sub 23 layer 2
# err loading roi data
# roi rglasser_MP_net sub 23 layer 3
# err loading roi data
# roi rglasser_MP_net sub 23 layer 4
# err loading roi data
# roi rglasser_MP_net sub 24 layer 2
# err loading roi data
# roi rglasser_MP_net sub 24 layer 3
# err loading roi data
# roi rglasser_MP_net sub 24 layer 4
# err loading roi data
# roi rglasser_MP_net sub 25 layer 2
# err loading roi data
# roi rglasser_MP_net sub 25 layer 3
# err loading roi data
# roi rglasser_MP_net sub 25 layer 4
# err loading roi data
# roi rglasser_MP_net sub 26 layer 2
# err loading roi data
# roi rglasser_MP_net sub 26 layer 3
# err loading roi data
# roi rglasser_MP_net sub 26 layer 4
# err loading roi data
# roi rglasser_MP_net sub 27 layer 2
# err loading roi data
# roi rglasser_MP_net sub 27 layer 3
# err loading roi data
# roi rglasser_MP_net sub 27 layer 4
# err loading roi data
# roi rglasser_MP_net sub 28 layer 2
# err loading roi data
# roi rglasser_MP_net sub 28 layer 3
# err loading roi data
# roi rglasser_MP_net sub 28 layer 4
# err loading roi data
# roi rglasser_MP_net sub 29 layer 2
# err loading roi data
# roi rglasser_MP_net sub 29 layer 3
# err loading roi data
# roi rglasser_MP_net sub 29 layer 4
# err loading roi data
# roi rglasser_MP_net sub 30 layer 2
# roi rglasser_MP_net sub 30 layer 3
# roi rglasser_MP_net sub 30 layer 4
# roi rglasser_MP_net sub 31 layer 2
# roi rglasser_MP_net sub 31 layer 3
# roi rglasser_MP_net sub 31 layer 4
# roi rglasser_MP_net sub 32 layer 2
# roi rglasser_MP_net sub 32 layer 3
# roi rglasser_MP_net sub 32 layer 4
# roi rglasser_MP_net sub 33 layer 2
# roi rglasser_MP_net sub 33 layer 3
# roi rglasser_MP_net sub 33 layer 4
# roi rglasser_MP_net sub 34 layer 2
# roi rglasser_MP_net sub 34 layer 3
# roi rglasser_MP_net sub 34 layer 4
# roi rglasser_MP_net sub 35 layer 2
# roi rglasser_MP_net sub 35 layer 3
# roi rglasser_MP_net sub 35 layer 4
# roi rglasser_MP_net sub 36 layer 2
# roi rglasser_MP_net sub 36 layer 3
# roi rglasser_MP_net sub 36 layer 4
# roi rglasser_MP_net sub 37 layer 2
# err getting classifier test data
# roi rglasser_MP_net sub 37 layer 3
# err getting classifier test data
# roi rglasser_MP_net sub 37 layer 4
# err getting classifier test data
# roi rglasser_MP_net sub 38 layer 2
# roi rglasser_MP_net sub 38 layer 3
# roi rglasser_MP_net sub 38 layer 4
# roi rglasser_MP_net sub 39 layer 2
# err loading roi data
# roi rglasser_MP_net sub 39 layer 3
# err loading roi data
# roi rglasser_MP_net sub 39 layer 4
# err loading roi data
# roi rglasser_MP_net sub 40 layer 2
# err loading roi data
# roi rglasser_MP_net sub 40 layer 3
# err loading roi data
# roi rglasser_MP_net sub 40 layer 4
# err loading roi data
# roi rglasser_MP_net sub 41 layer 2
# err loading roi data
# roi rglasser_MP_net sub 41 layer 3
# err loading roi data
# roi rglasser_MP_net sub 41 layer 4
# err loading roi data
# roi rglasser_MP_net sub 42 layer 2
# err loading roi data
# roi rglasser_MP_net sub 42 layer 3
# err loading roi data
# roi rglasser_MP_net sub 42 layer 4
# err loading roi data
# roi rglasser_MP_net sub 43 layer 2
# err loading roi data
# roi rglasser_MP_net sub 43 layer 3
# err loading roi data
# roi rglasser_MP_net sub 43 layer 4
# err loading roi data
# roi rglasser_MP_net sub 44 layer 2
# err loading roi data
# roi rglasser_MP_net sub 44 layer 3
# err loading roi data
# roi rglasser_MP_net sub 44 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 0 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 0 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 0 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 1 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 1 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 1 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 2 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 2 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 2 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 3 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 3 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 3 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 4 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 4 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 4 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 5 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 5 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 5 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 6 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 6 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 6 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 7 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 7 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 7 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 8 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 8 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 8 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 9 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 9 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 9 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 10 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 10 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 10 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 11 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 11 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 11 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 12 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 12 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 12 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 13 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 13 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 13 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 14 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 14 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 14 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 15 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 15 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 15 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 16 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 16 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 16 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 17 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 17 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 17 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 18 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 18 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 18 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 19 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 19 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 19 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 20 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 20 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 20 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 21 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 21 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 21 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 22 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 22 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 22 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 23 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 23 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 23 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 24 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 24 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 24 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 25 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 25 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 25 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 26 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 26 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 26 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 27 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 27 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 27 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 28 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 28 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 28 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 29 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 29 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 29 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 30 layer 2
# roi rglasser_MTN_net sub 30 layer 3
# roi rglasser_MTN_net sub 30 layer 4
# roi rglasser_MTN_net sub 31 layer 2
# roi rglasser_MTN_net sub 31 layer 3
# roi rglasser_MTN_net sub 31 layer 4
# roi rglasser_MTN_net sub 32 layer 2
# roi rglasser_MTN_net sub 32 layer 3
# roi rglasser_MTN_net sub 32 layer 4
# roi rglasser_MTN_net sub 33 layer 2
# roi rglasser_MTN_net sub 33 layer 3
# roi rglasser_MTN_net sub 33 layer 4
# roi rglasser_MTN_net sub 34 layer 2
# roi rglasser_MTN_net sub 34 layer 3
# roi rglasser_MTN_net sub 34 layer 4
# roi rglasser_MTN_net sub 35 layer 2
# roi rglasser_MTN_net sub 35 layer 3
# roi rglasser_MTN_net sub 35 layer 4
# roi rglasser_MTN_net sub 36 layer 2
# roi rglasser_MTN_net sub 36 layer 3
# roi rglasser_MTN_net sub 36 layer 4
# roi rglasser_MTN_net sub 37 layer 2
# err getting classifier test data
# roi rglasser_MTN_net sub 37 layer 3
# err getting classifier test data
# roi rglasser_MTN_net sub 37 layer 4
# err getting classifier test data
# roi rglasser_MTN_net sub 38 layer 2
# roi rglasser_MTN_net sub 38 layer 3
# roi rglasser_MTN_net sub 38 layer 4
# roi rglasser_MTN_net sub 39 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 39 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 39 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 40 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 40 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 40 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 41 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 41 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 41 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 42 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 42 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 42 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 43 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 43 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 43 layer 4
# err loading roi data
# roi rglasser_MTN_net sub 44 layer 2
# err loading roi data
# roi rglasser_MTN_net sub 44 layer 3
# err loading roi data
# roi rglasser_MTN_net sub 44 layer 4
# err loading roi data
# roi rglasser_PM_net sub 0 layer 2
# err loading roi data
# roi rglasser_PM_net sub 0 layer 3
# err loading roi data
# roi rglasser_PM_net sub 0 layer 4
# err loading roi data
# roi rglasser_PM_net sub 1 layer 2
# err loading roi data
# roi rglasser_PM_net sub 1 layer 3
# err loading roi data
# roi rglasser_PM_net sub 1 layer 4
# err loading roi data
# roi rglasser_PM_net sub 2 layer 2
# err loading roi data
# roi rglasser_PM_net sub 2 layer 3
# err loading roi data
# roi rglasser_PM_net sub 2 layer 4
# err loading roi data
# roi rglasser_PM_net sub 3 layer 2
# err loading roi data
# roi rglasser_PM_net sub 3 layer 3
# err loading roi data
# roi rglasser_PM_net sub 3 layer 4
# err loading roi data
# roi rglasser_PM_net sub 4 layer 2
# err loading roi data
# roi rglasser_PM_net sub 4 layer 3
# err loading roi data
# roi rglasser_PM_net sub 4 layer 4
# err loading roi data
# roi rglasser_PM_net sub 5 layer 2
# err loading roi data
# roi rglasser_PM_net sub 5 layer 3
# err loading roi data
# roi rglasser_PM_net sub 5 layer 4
# err loading roi data
# roi rglasser_PM_net sub 6 layer 2
# err loading roi data
# roi rglasser_PM_net sub 6 layer 3
# err loading roi data
# roi rglasser_PM_net sub 6 layer 4
# err loading roi data
# roi rglasser_PM_net sub 7 layer 2
# err loading roi data
# roi rglasser_PM_net sub 7 layer 3
# err loading roi data
# roi rglasser_PM_net sub 7 layer 4
# err loading roi data
# roi rglasser_PM_net sub 8 layer 2
# err loading roi data
# roi rglasser_PM_net sub 8 layer 3
# err loading roi data
# roi rglasser_PM_net sub 8 layer 4
# err loading roi data
# roi rglasser_PM_net sub 9 layer 2
# err loading roi data
# roi rglasser_PM_net sub 9 layer 3
# err loading roi data
# roi rglasser_PM_net sub 9 layer 4
# err loading roi data
# roi rglasser_PM_net sub 10 layer 2
# err loading roi data
# roi rglasser_PM_net sub 10 layer 3
# err loading roi data
# roi rglasser_PM_net sub 10 layer 4
# err loading roi data
# roi rglasser_PM_net sub 11 layer 2
# err loading roi data
# roi rglasser_PM_net sub 11 layer 3
# err loading roi data
# roi rglasser_PM_net sub 11 layer 4
# err loading roi data
# roi rglasser_PM_net sub 12 layer 2
# err loading roi data
# roi rglasser_PM_net sub 12 layer 3
# err loading roi data
# roi rglasser_PM_net sub 12 layer 4
# err loading roi data
# roi rglasser_PM_net sub 13 layer 2
# err loading roi data
# roi rglasser_PM_net sub 13 layer 3
# err loading roi data
# roi rglasser_PM_net sub 13 layer 4
# err loading roi data
# roi rglasser_PM_net sub 14 layer 2
# err loading roi data
# roi rglasser_PM_net sub 14 layer 3
# err loading roi data
# roi rglasser_PM_net sub 14 layer 4
# err loading roi data
# roi rglasser_PM_net sub 15 layer 2
# err loading roi data
# roi rglasser_PM_net sub 15 layer 3
# err loading roi data
# roi rglasser_PM_net sub 15 layer 4
# err loading roi data
# roi rglasser_PM_net sub 16 layer 2
# err loading roi data
# roi rglasser_PM_net sub 16 layer 3
# err loading roi data
# roi rglasser_PM_net sub 16 layer 4
# err loading roi data
# roi rglasser_PM_net sub 17 layer 2
# err loading roi data
# roi rglasser_PM_net sub 17 layer 3
# err loading roi data
# roi rglasser_PM_net sub 17 layer 4
# err loading roi data
# roi rglasser_PM_net sub 18 layer 2
# err loading roi data
# roi rglasser_PM_net sub 18 layer 3
# err loading roi data
# roi rglasser_PM_net sub 18 layer 4
# err loading roi data
# roi rglasser_PM_net sub 19 layer 2
# err loading roi data
# roi rglasser_PM_net sub 19 layer 3
# err loading roi data
# roi rglasser_PM_net sub 19 layer 4
# err loading roi data
# roi rglasser_PM_net sub 20 layer 2
# err loading roi data
# roi rglasser_PM_net sub 20 layer 3
# err loading roi data
# roi rglasser_PM_net sub 20 layer 4
# err loading roi data
# roi rglasser_PM_net sub 21 layer 2
# err loading roi data
# roi rglasser_PM_net sub 21 layer 3
# err loading roi data
# roi rglasser_PM_net sub 21 layer 4
# err loading roi data
# roi rglasser_PM_net sub 22 layer 2
# err loading roi data
# roi rglasser_PM_net sub 22 layer 3
# err loading roi data
# roi rglasser_PM_net sub 22 layer 4
# err loading roi data
# roi rglasser_PM_net sub 23 layer 2
# err loading roi data
# roi rglasser_PM_net sub 23 layer 3
# err loading roi data
# roi rglasser_PM_net sub 23 layer 4
# err loading roi data
# roi rglasser_PM_net sub 24 layer 2
# err loading roi data
# roi rglasser_PM_net sub 24 layer 3
# err loading roi data
# roi rglasser_PM_net sub 24 layer 4
# err loading roi data
# roi rglasser_PM_net sub 25 layer 2
# err loading roi data
# roi rglasser_PM_net sub 25 layer 3
# err loading roi data
# roi rglasser_PM_net sub 25 layer 4
# err loading roi data
# roi rglasser_PM_net sub 26 layer 2
# err loading roi data
# roi rglasser_PM_net sub 26 layer 3
# err loading roi data
# roi rglasser_PM_net sub 26 layer 4
# err loading roi data
# roi rglasser_PM_net sub 27 layer 2
# err loading roi data
# roi rglasser_PM_net sub 27 layer 3
# err loading roi data
# roi rglasser_PM_net sub 27 layer 4
# err loading roi data
# roi rglasser_PM_net sub 28 layer 2
# err loading roi data
# roi rglasser_PM_net sub 28 layer 3
# err loading roi data
# roi rglasser_PM_net sub 28 layer 4
# err loading roi data
# roi rglasser_PM_net sub 29 layer 2
# err loading roi data
# roi rglasser_PM_net sub 29 layer 3
# err loading roi data
# roi rglasser_PM_net sub 29 layer 4
# err loading roi data
# roi rglasser_PM_net sub 30 layer 2
# roi rglasser_PM_net sub 30 layer 3
# roi rglasser_PM_net sub 30 layer 4
# roi rglasser_PM_net sub 31 layer 2
# roi rglasser_PM_net sub 31 layer 3
# roi rglasser_PM_net sub 31 layer 4
# roi rglasser_PM_net sub 32 layer 2
# roi rglasser_PM_net sub 32 layer 3
# roi rglasser_PM_net sub 32 layer 4
# roi rglasser_PM_net sub 33 layer 2
# roi rglasser_PM_net sub 33 layer 3
# roi rglasser_PM_net sub 33 layer 4
# roi rglasser_PM_net sub 34 layer 2
# roi rglasser_PM_net sub 34 layer 3
# roi rglasser_PM_net sub 34 layer 4
# roi rglasser_PM_net sub 35 layer 2
# roi rglasser_PM_net sub 35 layer 3
# roi rglasser_PM_net sub 35 layer 4
# roi rglasser_PM_net sub 36 layer 2
# roi rglasser_PM_net sub 36 layer 3
# roi rglasser_PM_net sub 36 layer 4
# roi rglasser_PM_net sub 37 layer 2
# err getting classifier test data
# roi rglasser_PM_net sub 37 layer 3
# err getting classifier test data
# roi rglasser_PM_net sub 37 layer 4
# err getting classifier test data
# roi rglasser_PM_net sub 38 layer 2
# roi rglasser_PM_net sub 38 layer 3
# roi rglasser_PM_net sub 38 layer 4
# roi rglasser_PM_net sub 39 layer 2
# err loading roi data
# roi rglasser_PM_net sub 39 layer 3
# err loading roi data
# roi rglasser_PM_net sub 39 layer 4
# err loading roi data
# roi rglasser_PM_net sub 40 layer 2
# err loading roi data
# roi rglasser_PM_net sub 40 layer 3
# err loading roi data
# roi rglasser_PM_net sub 40 layer 4
# err loading roi data
# roi rglasser_PM_net sub 41 layer 2
# err loading roi data
# roi rglasser_PM_net sub 41 layer 3
# err loading roi data
# roi rglasser_PM_net sub 41 layer 4
# err loading roi data
# roi rglasser_PM_net sub 42 layer 2
# err loading roi data
# roi rglasser_PM_net sub 42 layer 3
# err loading roi data
# roi rglasser_PM_net sub 42 layer 4
# err loading roi data
# roi rglasser_PM_net sub 43 layer 2
# err loading roi data
# roi rglasser_PM_net sub 43 layer 3
# err loading roi data
# roi rglasser_PM_net sub 43 layer 4
# err loading roi data
# roi rglasser_PM_net sub 44 layer 2
# err loading roi data
# roi rglasser_PM_net sub 44 layer 3
# err loading roi data
# roi rglasser_PM_net sub 44 layer 4
# err loading roi data
# roi rhippocampusAAL sub 0 layer 2
# err loading roi data
# roi rhippocampusAAL sub 0 layer 3
# err loading roi data
# roi rhippocampusAAL sub 0 layer 4
# err loading roi data
# roi rhippocampusAAL sub 1 layer 2
# err loading roi data
# roi rhippocampusAAL sub 1 layer 3
# err loading roi data
# roi rhippocampusAAL sub 1 layer 4
# err loading roi data
# roi rhippocampusAAL sub 2 layer 2
# err loading roi data
# roi rhippocampusAAL sub 2 layer 3
# err loading roi data
# roi rhippocampusAAL sub 2 layer 4
# err loading roi data
# roi rhippocampusAAL sub 3 layer 2
# err loading roi data
# roi rhippocampusAAL sub 3 layer 3
# err loading roi data
# roi rhippocampusAAL sub 3 layer 4
# err loading roi data
# roi rhippocampusAAL sub 4 layer 2
# err loading roi data
# roi rhippocampusAAL sub 4 layer 3
# err loading roi data
# roi rhippocampusAAL sub 4 layer 4
# err loading roi data
# roi rhippocampusAAL sub 5 layer 2
# err loading roi data
# roi rhippocampusAAL sub 5 layer 3
# err loading roi data
# roi rhippocampusAAL sub 5 layer 4
# err loading roi data
# roi rhippocampusAAL sub 6 layer 2
# err loading roi data
# roi rhippocampusAAL sub 6 layer 3
# err loading roi data
# roi rhippocampusAAL sub 6 layer 4
# err loading roi data
# roi rhippocampusAAL sub 7 layer 2
# err loading roi data
# roi rhippocampusAAL sub 7 layer 3
# err loading roi data
# roi rhippocampusAAL sub 7 layer 4
# err loading roi data
# roi rhippocampusAAL sub 8 layer 2
# err loading roi data
# roi rhippocampusAAL sub 8 layer 3
# err loading roi data
# roi rhippocampusAAL sub 8 layer 4
# err loading roi data
# roi rhippocampusAAL sub 9 layer 2
# err loading roi data
# roi rhippocampusAAL sub 9 layer 3
# err loading roi data
# roi rhippocampusAAL sub 9 layer 4
# err loading roi data
# roi rhippocampusAAL sub 10 layer 2
# err loading roi data
# roi rhippocampusAAL sub 10 layer 3
# err loading roi data
# roi rhippocampusAAL sub 10 layer 4
# err loading roi data
# roi rhippocampusAAL sub 11 layer 2
# err loading roi data
# roi rhippocampusAAL sub 11 layer 3
# err loading roi data
# roi rhippocampusAAL sub 11 layer 4
# err loading roi data
# roi rhippocampusAAL sub 12 layer 2
# err loading roi data
# roi rhippocampusAAL sub 12 layer 3
# err loading roi data
# roi rhippocampusAAL sub 12 layer 4
# err loading roi data
# roi rhippocampusAAL sub 13 layer 2
# err loading roi data
# roi rhippocampusAAL sub 13 layer 3
# err loading roi data
# roi rhippocampusAAL sub 13 layer 4
# err loading roi data
# roi rhippocampusAAL sub 14 layer 2
# err loading roi data
# roi rhippocampusAAL sub 14 layer 3
# err loading roi data
# roi rhippocampusAAL sub 14 layer 4
# err loading roi data
# roi rhippocampusAAL sub 15 layer 2
# err loading roi data
# roi rhippocampusAAL sub 15 layer 3
# err loading roi data
# roi rhippocampusAAL sub 15 layer 4
# err loading roi data
# roi rhippocampusAAL sub 16 layer 2
# err loading roi data
# roi rhippocampusAAL sub 16 layer 3
# err loading roi data
# roi rhippocampusAAL sub 16 layer 4
# err loading roi data
# roi rhippocampusAAL sub 17 layer 2
# err loading roi data
# roi rhippocampusAAL sub 17 layer 3
# err loading roi data
# roi rhippocampusAAL sub 17 layer 4
# err loading roi data
# roi rhippocampusAAL sub 18 layer 2
# err loading roi data
# roi rhippocampusAAL sub 18 layer 3
# err loading roi data
# roi rhippocampusAAL sub 18 layer 4
# err loading roi data
# roi rhippocampusAAL sub 19 layer 2
# err loading roi data
# roi rhippocampusAAL sub 19 layer 3
# err loading roi data
# roi rhippocampusAAL sub 19 layer 4
# err loading roi data
# roi rhippocampusAAL sub 20 layer 2
# err loading roi data
# roi rhippocampusAAL sub 20 layer 3
# err loading roi data
# roi rhippocampusAAL sub 20 layer 4
# err loading roi data
# roi rhippocampusAAL sub 21 layer 2
# err loading roi data
# roi rhippocampusAAL sub 21 layer 3
# err loading roi data
# roi rhippocampusAAL sub 21 layer 4
# err loading roi data
# roi rhippocampusAAL sub 22 layer 2
# err loading roi data
# roi rhippocampusAAL sub 22 layer 3
# err loading roi data
# roi rhippocampusAAL sub 22 layer 4
# err loading roi data
# roi rhippocampusAAL sub 23 layer 2
# err loading roi data
# roi rhippocampusAAL sub 23 layer 3
# err loading roi data
# roi rhippocampusAAL sub 23 layer 4
# err loading roi data
# roi rhippocampusAAL sub 24 layer 2
# err loading roi data
# roi rhippocampusAAL sub 24 layer 3
# err loading roi data
# roi rhippocampusAAL sub 24 layer 4
# err loading roi data
# roi rhippocampusAAL sub 25 layer 2
# err loading roi data
# roi rhippocampusAAL sub 25 layer 3
# err loading roi data
# roi rhippocampusAAL sub 25 layer 4
# err loading roi data
# roi rhippocampusAAL sub 26 layer 2
# err loading roi data
# roi rhippocampusAAL sub 26 layer 3
# err loading roi data
# roi rhippocampusAAL sub 26 layer 4
# err loading roi data
# roi rhippocampusAAL sub 27 layer 2
# err loading roi data
# roi rhippocampusAAL sub 27 layer 3
# err loading roi data
# roi rhippocampusAAL sub 27 layer 4
# err loading roi data
# roi rhippocampusAAL sub 28 layer 2
# err loading roi data
# roi rhippocampusAAL sub 28 layer 3
# err loading roi data
# roi rhippocampusAAL sub 28 layer 4
# err loading roi data
# roi rhippocampusAAL sub 29 layer 2
# err loading roi data
# roi rhippocampusAAL sub 29 layer 3
# err loading roi data
# roi rhippocampusAAL sub 29 layer 4
# err loading roi data
# roi rhippocampusAAL sub 30 layer 2
# roi rhippocampusAAL sub 30 layer 3
# roi rhippocampusAAL sub 30 layer 4
# roi rhippocampusAAL sub 31 layer 2
# roi rhippocampusAAL sub 31 layer 3
# roi rhippocampusAAL sub 31 layer 4
# roi rhippocampusAAL sub 32 layer 2
# roi rhippocampusAAL sub 32 layer 3
# roi rhippocampusAAL sub 32 layer 4
# roi rhippocampusAAL sub 33 layer 2
# roi rhippocampusAAL sub 33 layer 3
# roi rhippocampusAAL sub 33 layer 4
# roi rhippocampusAAL sub 34 layer 2
# roi rhippocampusAAL sub 34 layer 3
# roi rhippocampusAAL sub 34 layer 4
# roi rhippocampusAAL sub 35 layer 2
# roi rhippocampusAAL sub 35 layer 3
# roi rhippocampusAAL sub 35 layer 4
# roi rhippocampusAAL sub 36 layer 2
# roi rhippocampusAAL sub 36 layer 3
# roi rhippocampusAAL sub 36 layer 4
# roi rhippocampusAAL sub 37 layer 2
# err getting classifier test data
# roi rhippocampusAAL sub 37 layer 3
# err getting classifier test data
# roi rhippocampusAAL sub 37 layer 4
# err getting classifier test data
# roi rhippocampusAAL sub 38 layer 2
# roi rhippocampusAAL sub 38 layer 3
# roi rhippocampusAAL sub 38 layer 4
# roi rhippocampusAAL sub 39 layer 2
# err loading roi data
# roi rhippocampusAAL sub 39 layer 3
# err loading roi data
# roi rhippocampusAAL sub 39 layer 4
# err loading roi data
# roi rhippocampusAAL sub 40 layer 2
# err loading roi data
# roi rhippocampusAAL sub 40 layer 3
# err loading roi data
# roi rhippocampusAAL sub 40 layer 4
# err loading roi data
# roi rhippocampusAAL sub 41 layer 2
# err loading roi data
# roi rhippocampusAAL sub 41 layer 3
# err loading roi data
# roi rhippocampusAAL sub 41 layer 4
# err loading roi data
# roi rhippocampusAAL sub 42 layer 2
# err loading roi data
# roi rhippocampusAAL sub 42 layer 3
# err loading roi data
# roi rhippocampusAAL sub 42 layer 4
# err loading roi data
# roi rhippocampusAAL sub 43 layer 2
# err loading roi data
# roi rhippocampusAAL sub 43 layer 3
# err loading roi data
# roi rhippocampusAAL sub 43 layer 4
# err loading roi data
# roi rhippocampusAAL sub 44 layer 2
# err loading roi data
# roi rhippocampusAAL sub 44 layer 3
# err loading roi data
# roi rhippocampusAAL sub 44 layer 4
# err loading roi data

# %%
results
# Out:
#      sub_num                roi  layer  num_test_samples     score
# 0         30  SnPM_filtered_FDR      2               354  0.525424
# 1         30  SnPM_filtered_FDR      3               354  0.471751
# 2         30  SnPM_filtered_FDR      4               354  0.480226
# 3         31  SnPM_filtered_FDR      2               256  0.464844
# 4         31  SnPM_filtered_FDR      3               256  0.460938
# 5         31  SnPM_filtered_FDR      4               256  0.457031
# 6         32  SnPM_filtered_FDR      2               211  0.502370
# 7         32  SnPM_filtered_FDR      3               211  0.540284
# 8         32  SnPM_filtered_FDR      4               211  0.483412
# 9         33  SnPM_filtered_FDR      2               524  0.488550
# 10        33  SnPM_filtered_FDR      3               524  0.501908
# 11        33  SnPM_filtered_FDR      4               524  0.522901
# 12        34  SnPM_filtered_FDR      2               509  0.471513
# 13        34  SnPM_filtered_FDR      3               509  0.506876
# 14        34  SnPM_filtered_FDR      4               509  0.465619
# 15        35  SnPM_filtered_FDR      2               771  0.516213
# 16        35  SnPM_filtered_FDR      3               771  0.474708
# 17        35  SnPM_filtered_FDR      4               771  0.491569
# 18        36  SnPM_filtered_FDR      2               396  0.555556
# 19        36  SnPM_filtered_FDR      3               396  0.482323
# 20        36  SnPM_filtered_FDR      4               396  0.444444
# 21        30    rglasser_AT_net      2               354  0.491525
# 22        30    rglasser_AT_net      3               354  0.548023
# 23        30    rglasser_AT_net      4               354  0.545198
# 24        31    rglasser_AT_net      2               256  0.496094
# 25        31    rglasser_AT_net      3               256  0.562500
# 26        31    rglasser_AT_net      4               256  0.476562
# 27        32    rglasser_AT_net      2               211  0.535545
# 28        32    rglasser_AT_net      3               211  0.492891
# 29        32    rglasser_AT_net      4               211  0.459716
# 30        33    rglasser_AT_net      2               524  0.467557
# 31        33    rglasser_AT_net      3               524  0.503817
# 32        33    rglasser_AT_net      4               524  0.532443
# 33        34    rglasser_AT_net      2               509  0.512770
# 34        34    rglasser_AT_net      3               509  0.520629
# 35        34    rglasser_AT_net      4               509  0.506876
# 36        35    rglasser_AT_net      2               771  0.508431
# 37        35    rglasser_AT_net      3               771  0.508431
# 38        35    rglasser_AT_net      4               771  0.508431
# 39        36    rglasser_AT_net      2               396  0.502525
# 40        36    rglasser_AT_net      3               396  0.517677
# 41        36    rglasser_AT_net      4               396  0.472222
# 42        38    rglasser_AT_net      2               276  0.507246
# 43        38    rglasser_AT_net      3               276  0.492754
# 44        38    rglasser_AT_net      4               276  0.449275
# 45        30    rglasser_MP_net      2               354  0.488701
# 46        30    rglasser_MP_net      3               354  0.437853
# 47        30    rglasser_MP_net      4               354  0.519774
# 48        31    rglasser_MP_net      2               256  0.515625
# 49        31    rglasser_MP_net      3               256  0.566406
# 50        31    rglasser_MP_net      4               256  0.460938
# 51        32    rglasser_MP_net      2               211  0.502370
# 52        32    rglasser_MP_net      3               211  0.473934
# 53        32    rglasser_MP_net      4               211  0.526066
# 54        33    rglasser_MP_net      2               524  0.479008
# 55        33    rglasser_MP_net      3               524  0.513359
# 56        33    rglasser_MP_net      4               524  0.524809
# 57        34    rglasser_MP_net      2               509  0.514735
# 58        34    rglasser_MP_net      3               509  0.485265
# 59        34    rglasser_MP_net      4               509  0.518664
# 60        35    rglasser_MP_net      2               771  0.517510
# 61        35    rglasser_MP_net      3               771  0.487678
# 62        35    rglasser_MP_net      4               771  0.487678
# 63        36    rglasser_MP_net      2               396  0.510101
# 64        36    rglasser_MP_net      3               396  0.517677
# 65        36    rglasser_MP_net      4               396  0.464646
# 66        38    rglasser_MP_net      2               276  0.503623
# 67        38    rglasser_MP_net      3               276  0.550725
# 68        38    rglasser_MP_net      4               276  0.452899
# 69        30   rglasser_MTN_net      2               354  0.519774
# 70        30   rglasser_MTN_net      3               354  0.483051
# 71        30   rglasser_MTN_net      4               354  0.483051
# 72        31   rglasser_MTN_net      2               256  0.449219
# 73        31   rglasser_MTN_net      3               256  0.527344
# 74        31   rglasser_MTN_net      4               256  0.421875
# 75        32   rglasser_MTN_net      2               211  0.445498
# 76        32   rglasser_MTN_net      3               211  0.521327
# 77        32   rglasser_MTN_net      4               211  0.488152
# 78        33   rglasser_MTN_net      2               524  0.522901
# 79        33   rglasser_MTN_net      3               524  0.494275
# 80        33   rglasser_MTN_net      4               524  0.541985
# 81        34   rglasser_MTN_net      2               509  0.499018
# 82        34   rglasser_MTN_net      3               509  0.479371
# 83        34   rglasser_MTN_net      4               509  0.500982
# 84        35   rglasser_MTN_net      2               771  0.516213
# 85        35   rglasser_MTN_net      3               771  0.499351
# 86        35   rglasser_MTN_net      4               771  0.491569
# 87        36   rglasser_MTN_net      2               396  0.457071
# 88        36   rglasser_MTN_net      3               396  0.507576
# 89        36   rglasser_MTN_net      4               396  0.489899
# 90        38   rglasser_MTN_net      2               276  0.532609
# 91        38   rglasser_MTN_net      3               276  0.561594
# 92        38   rglasser_MTN_net      4               276  0.467391
# 93        30    rglasser_PM_net      2               354  0.516949
# 94        30    rglasser_PM_net      3               354  0.497175
# 95        30    rglasser_PM_net      4               354  0.466102
# 96        31    rglasser_PM_net      2               256  0.449219
# 97        31    rglasser_PM_net      3               256  0.609375
# 98        31    rglasser_PM_net      4               256  0.488281
# 99        32    rglasser_PM_net      2               211  0.450237
# 100       32    rglasser_PM_net      3               211  0.469194
# 101       32    rglasser_PM_net      4               211  0.535545
# 102       33    rglasser_PM_net      2               524  0.496183
# 103       33    rglasser_PM_net      3               524  0.500000
# 104       33    rglasser_PM_net      4               524  0.511450
# 105       34    rglasser_PM_net      2               509  0.518664
# 106       34    rglasser_PM_net      3               509  0.500982
# 107       34    rglasser_PM_net      4               509  0.526523
# 108       35    rglasser_PM_net      2               771  0.500649
# 109       35    rglasser_PM_net      3               771  0.499351
# 110       35    rglasser_PM_net      4               771  0.491569
# 111       36    rglasser_PM_net      2               396  0.505051
# 112       36    rglasser_PM_net      3               396  0.512626
# 113       36    rglasser_PM_net      4               396  0.520202
# 114       38    rglasser_PM_net      2               276  0.514493
# 115       38    rglasser_PM_net      3               276  0.503623
# 116       38    rglasser_PM_net      4               276  0.514493
# 117       30    rhippocampusAAL      2               354  0.533898
# 118       30    rhippocampusAAL      3               354  0.511299
# 119       30    rhippocampusAAL      4               354  0.502825
# 120       31    rhippocampusAAL      2               256  0.472656
# 121       31    rhippocampusAAL      3               256  0.566406
# 122       31    rhippocampusAAL      4               256  0.519531
# 123       32    rhippocampusAAL      2               211  0.436019
# 124       32    rhippocampusAAL      3               211  0.535545
# 125       32    rhippocampusAAL      4               211  0.483412
# 126       33    rhippocampusAAL      2               524  0.513359
# 127       33    rhippocampusAAL      3               524  0.522901
# 128       33    rhippocampusAAL      4               524  0.522901
# 129       34    rhippocampusAAL      2               509  0.467583
# 130       34    rhippocampusAAL      3               509  0.481336
# 131       34    rhippocampusAAL      4               509  0.504912
# 132       35    rhippocampusAAL      2               771  0.507134
# 133       35    rhippocampusAAL      3               771  0.513619
# 134       35    rhippocampusAAL      4               771  0.501946
# 135       36    rhippocampusAAL      2               396  0.431818
# 136       36    rhippocampusAAL      3               396  0.487374
# 137       36    rhippocampusAAL      4               396  0.479798
# 138       38    rhippocampusAAL      2               276  0.496377
# 139       38    rhippocampusAAL      3               276  0.525362
# 140       38    rhippocampusAAL      4               276  0.463768

# %%
Nsubs = len(results.sub_num.unique())
results.to_csv('data/analyses/decodeState_trainView_testRecall-eval_on_path-N%i.csv'%Nsubs)
