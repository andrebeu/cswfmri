# %% [markdown]
# * creates `exp_timing.csv`
# - make and save a dataframe containing the onset TR for each event in the experiment
# - average across subjects to get a single common TR that will be used to index functional data

# %%
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt

import sklearn
import brainiak
import nilearn as nl
from nilearn import image, plotting, input_data

from scipy.spatial import distance

from utils import *
pd.options.display.max_rows = 200

# %%
def read_logfile(sub_num,task='recall'):
  """ 
  read psychopy logifle into dataframe
  """
  # initialize dataframe
  df = pd.DataFrame(columns=['tstamp','logdata'])
  df = df.astype({'tstamp':float})
  # open logfile
  fpath = 'behav/silvy_buckets/sub%iday2/%i_%s.log'%(100+sub_num,sub_num,task)
  f = open(fpath, "r")
  # loop over logfile rows
  for x in f:
    tstamp,B,C = x.split('\t')
    tstamp = float(tstamp)
#     df.loc[tstamp,'logtype'] = B[:-1]
    df.loc[tstamp,'logdata'] = C[:-1]
    df.loc[tstamp,'tstamp'] = tstamp
  return df

def reindex_and_TR_column(df):
  TR_rate = 1.5
  # first TR
  first_TR_tstamp = df[df.logdata=='Keypress: equal'].iloc[0].tstamp
  # center tstamps on first TR
  df.tstamp = df.tstamp-first_TR_tstamp
  # include TR column
  df['TR'] = np.ceil(df.tstamp/TR_rate)
  df = df.astype({'TR':int})
  # remove negative TRs
  df = df[df.TR>-1]
  # reindex by row number
  df.index = np.arange(len(df))
  return df

def include_wed_cols(df):
  ''' includes columns with wed_num and wed_id 
  '''
  df.loc[:,'wed_num'] = 99
  df.loc[:,'wed_id'] = 99
  wed_start_idx = df[df.logdata.str[:len("New trial")]=="New trial"].index
  wed_id_series = df.iloc[wed_start_idx].logdata.str.split('/').str[-1].str.split('.').str[0].str[1:]
  for wed_num,(t0,t1,wed_id) in enumerate(zip(wed_start_idx[:-1],wed_start_idx[1:],wed_id_series)):
    df.loc[t0:t1,'wed_num']=wed_num
    df.loc[t0:t1,'wed_id']=wed_id
  df.loc[wed_start_idx[-1]:,'wed_num']=11
  df.loc[wed_start_idx[-1]:,'wed_id']=wed_id_series.iloc[-1]
  return df

# %%
df = read_logfile(31)
df = reindex_and_TR_column(df)
df = include_wed_cols(df)
df.iloc[:200]
# Out:
#        tstamp                                            logdata   TR  \
# 0      0.0000                                    Keypress: equal    0
# 1      0.0094  Imported recall.csv as conditions, 12 conditio...    1
# 2      0.0119  Created sequence: random, trialTypes=12, nReps...    1
# 3      0.0123  New trial (rep=0, index=0): OrderedDict([('cue...    1
# 4      0.0658                              text: autoDraw = True    1
# 5      1.5000                                    Keypress: equal    1
# 6      3.0001                                    Keypress: equal    3
# 7      4.4999                                    Keypress: equal    3
# 8      6.0003                                    Keypress: equal    5
# 9      7.5001                                    Keypress: equal    6
# 10     8.9997                                    Keypress: equal    6
# 11    10.4999                                    Keypress: equal    7
# 12    12.0045                                    Keypress: equal    9
# 13    13.5046                                    Keypress: equal   10
# 14    15.0088                                    Keypress: equal   11
# 15    16.4999                                    Keypress: equal   11
# 16    17.9999                                    Keypress: equal   12
# 17    19.5003                                    Keypress: equal   14
# 18    21.0084                                    Keypress: equal   15
# 19    22.5088                                    Keypress: equal   16
# 20    24.0045                                    Keypress: equal   17
# 21    25.5096                                    Keypress: equal   18
# 22    27.0002                                    Keypress: equal   19
# 23    27.3661                                    Keypress: space   19
# 24    27.5113  New trial (rep=0, index=1): OrderedDict([('cue...   19
# 25    27.5324                              text: autoDraw = True   19
# 26    28.5002                                    Keypress: equal   20
# 27    30.0054                                    Keypress: equal   21
# 28    31.5046                                    Keypress: equal   22
# 29    33.0042                                    Keypress: equal   23
# 30    34.5040                                    Keypress: equal   24
# 31    36.0044                                    Keypress: equal   25
# 32    37.5044                                    Keypress: equal   26
# 33    39.0001                                    Keypress: equal   27
# 34    40.5047                                    Keypress: equal   28
# 35    42.0089                                    Keypress: equal   29
# 36    43.5089                                    Keypress: equal   30
# 37    45.0095                                    Keypress: equal   31
# 38    46.5005                                    Keypress: equal   32
# 39    48.0042                                    Keypress: equal   33
# 40    49.5001                                    Keypress: equal   34
# 41    51.0001                                    Keypress: equal   35
# 42    52.5034                                    Keypress: equal   36
# 43    54.0037                                    Keypress: equal   37
# 44    55.5040                                    Keypress: equal   38
# 45    57.0035                                    Keypress: equal   39
# 46    58.5001                                    Keypress: equal   40
# 47    60.0003                                    Keypress: equal   41
# 48    61.4995                                    Keypress: equal   41
# 49    63.0042                                    Keypress: equal   43
# 50    64.5004                                    Keypress: equal   44
# 51    65.9372                                    Keypress: space   44
# 52    66.0864  New trial (rep=0, index=2): OrderedDict([('cue...   45
# 53    66.0976                                    Keypress: equal   45
# 54    66.1144                              text: autoDraw = True   45
# 55    67.5043                                    Keypress: equal   46
# 56    69.0041                                    Keypress: equal   47
# 57    70.5040                                    Keypress: equal   48
# 58    72.0030                                    Keypress: equal   49
# 59    73.5034                                    Keypress: equal   50
# 60    75.0040                                    Keypress: equal   51
# 61    76.5041                                    Keypress: equal   52
# 62    78.0035                                    Keypress: equal   53
# 63    79.5042                                    Keypress: equal   54
# 64    80.9990                                    Keypress: equal   54
# 65    82.4995                                    Keypress: equal   55
# 66    83.9995                                    Keypress: equal   56
# 67    85.4997                                    Keypress: equal   57
# 68    86.9996                                    Keypress: equal   58
# 69    87.3159                                    Keypress: space   59
# 70    87.4590  New trial (rep=0, index=3): OrderedDict([('cue...   59
# 71    87.4815                              text: autoDraw = True   59
# 72    88.4993                                    Keypress: equal   59
# 73    89.9994                                    Keypress: equal   60
# 74    91.5041                                    Keypress: equal   62
# 75    93.0036                                    Keypress: equal   63
# 76    94.5036                                    Keypress: equal   64
# 77    95.9993                                    Keypress: equal   64
# 78    97.4994                                    Keypress: equal   65
# 79    98.9995                                    Keypress: equal   66
# 80   100.4996                                    Keypress: equal   67
# 81   102.0037                                    Keypress: equal   69
# 82   103.5038                                    Keypress: equal   70
# 83   105.0041                                    Keypress: equal   71
# 84   106.4996                                    Keypress: equal   71
# 85   107.9993                                    Keypress: equal   72
# 86   109.4994                                    Keypress: equal   73
# 87   111.0037                                    Keypress: equal   75
# 88   112.4993                                    Keypress: equal   75
# 89   113.9993                                    Keypress: equal   76
# 90   115.4994                                    Keypress: equal   77
# 91   117.0042                                    Keypress: equal   79
# 92   118.5040                                    Keypress: equal   80
# 93   120.0040                                    Keypress: equal   81
# 94   121.4994                                    Keypress: equal   81
# 95   122.9983                                    Keypress: equal   82
# 96   124.4994                                    Keypress: equal   83
# 97   125.9993                                    Keypress: equal   84
# 98   127.5028                                    Keypress: equal   86
# 99   128.9983                                    Keypress: equal   86
# 100  129.4203                                    Keypress: space   87
# 101  129.5716  New trial (rep=0, index=4): OrderedDict([('cue...   87
# 102  129.5975                              text: autoDraw = True   87
# 103  130.4987                                    Keypress: equal   87
# 104  131.9984                                    Keypress: equal   88
# 105  133.4985                                    Keypress: equal   89
# 106  134.9985                                    Keypress: equal   90
# 107  136.5079                                    Keypress: equal   92
# 108  138.0072                                    Keypress: equal   93
# 109  139.5075                                    Keypress: equal   94
# 110  141.0069                                    Keypress: equal   95
# 111  142.5033                                    Keypress: equal   96
# 112  143.9994                                    Keypress: equal   96
# 113  145.4982                                    Keypress: equal   97
# 114  146.9986                                    Keypress: equal   98
# 115  148.4980                                    Keypress: equal   99
# 116  150.0032                                    Keypress: equal  101
# 117  151.5029                                    Keypress: equal  102
# 118  153.0030                                    Keypress: equal  103
# 119  154.5022                                    Keypress: equal  104
# 120  156.0036                                    Keypress: equal  105
# 121  157.4983                                    Keypress: equal  105
# 122  158.9984                                    Keypress: equal  106
# 123  160.4986                                    Keypress: equal  107
# 124  161.9988                                    Keypress: equal  108
# 125  163.4987                                    Keypress: equal  109
# 126  164.9987                                    Keypress: equal  110
# 127  165.2384                                    Keypress: space  111
# 128  165.3804  New trial (rep=0, index=5): OrderedDict([('cue...  111
# 129  165.4142                              text: autoDraw = True  111
# 130  166.4987                                    Keypress: equal  111
# 131  167.9989                                    Keypress: equal  112
# 132  169.4991                                    Keypress: equal  113
# 133  170.9988                                    Keypress: equal  114
# 134  172.4987                                    Keypress: equal  115
# 135  173.9987                                    Keypress: equal  116
# 136  175.4989                                    Keypress: equal  117
# 137  176.9990                                    Keypress: equal  118
# 138  178.4989                                    Keypress: equal  119
# 139  179.9988                                    Keypress: equal  120
# 140  181.5027                                    Keypress: equal  122
# 141  183.0020                                    Keypress: equal  123
# 142  184.4986                                    Keypress: equal  123
# 143  185.9975                                    Keypress: equal  124
# 144  187.4977                                    Keypress: equal  125
# 145  188.9987                                    Keypress: equal  126
# 146  190.5028                                    Keypress: equal  128
# 147  191.9976                                    Keypress: equal  128
# 148  193.5023                                    Keypress: equal  130
# 149  195.0017                                    Keypress: equal  131
# 150  195.0652                                    Keypress: space  131
# 151  195.1994  New trial (rep=0, index=6): OrderedDict([('cue...  131
# 152  195.2294                              text: autoDraw = True  131
# 153  196.4920                                    Keypress: equal  131
# 154  197.9909                                    Keypress: equal  132
# 155  199.5074                                    Keypress: equal  134
# 156  201.0068                                    Keypress: equal  135
# 157  202.4976                                    Keypress: equal  135
# 158  203.9984                                    Keypress: equal  136
# 159  205.5029                                    Keypress: equal  138
# 160  207.0015                                    Keypress: equal  139
# 161  208.5023                                    Keypress: equal  140
# 162  209.9973                                    Keypress: equal  140
# 163  211.5019                                    Keypress: equal  142
# 164  213.0021                                    Keypress: equal  143
# 165  214.5014                                    Keypress: equal  144
# 166  216.0027                                    Keypress: equal  145
# 167  217.5021                                    Keypress: equal  146
# 168  218.9978                                    Keypress: equal  146
# 169  220.4974                                    Keypress: equal  147
# 170  221.1640                                    Keypress: space  148
# 171  221.2956  New trial (rep=0, index=7): OrderedDict([('cue...  148
# 172  221.3295                              text: autoDraw = True  148
# 173  221.9981                                    Keypress: equal  148
# 174  223.5014                                    Keypress: equal  150
# 175  224.9980                                    Keypress: equal  150
# 176  226.5012                                    Keypress: equal  152
# 177  228.0015                                    Keypress: equal  153
# 178  229.5021                                    Keypress: equal  154
# 179  231.0023                                    Keypress: equal  155
# 180  232.5017                                    Keypress: equal  156
# 181  234.0024                                    Keypress: equal  157
# 182  235.4976                                    Keypress: equal  157
# 183  237.0059                                    Keypress: equal  159
# 184  238.5064                                    Keypress: equal  160
# 185  238.8188                                    Keypress: space  160
# 186  238.9610  New trial (rep=0, index=8): OrderedDict([('cue...  160
# 187  238.9799                              text: autoDraw = True  160
# 188  240.0019                                    Keypress: equal  161
# 189  241.4981                                    Keypress: equal  161
# 190  242.9980                                    Keypress: equal  162
# 191  244.4979                                    Keypress: equal  163
# 192  245.9967                                    Keypress: equal  164
# 193  247.4971                                    Keypress: equal  165
# 194  248.9981                                    Keypress: equal  166
# 195  250.4969                                    Keypress: equal  167
# 196  251.9890                                    Keypress: equal  168
# 197  253.4897                                    Keypress: equal  169
# 198  254.9887                                    Keypress: equal  170
# 199  256.4972                                    Keypress: equal  171
#
#      wed_num wed_id
# 0         99     99
# 1         99     99
# 2         99     99
# 3          0     29
# 4          0     29
# 5          0     29
# 6          0     29
# 7          0     29
# 8          0     29
# 9          0     29
# 10         0     29
# 11         0     29
# 12         0     29
# 13         0     29
# 14         0     29
# 15         0     29
# 16         0     29
# 17         0     29
# 18         0     29
# 19         0     29
# 20         0     29
# 21         0     29
# 22         0     29
# 23         0     29
# 24         1     34
# 25         1     34
# 26         1     34
# 27         1     34
# 28         1     34
# 29         1     34
# 30         1     34
# 31         1     34
# 32         1     34
# 33         1     34
# 34         1     34
# 35         1     34
# 36         1     34
# 37         1     34
# 38         1     34
# 39         1     34
# 40         1     34
# 41         1     34
# 42         1     34
# 43         1     34
# 44         1     34
# 45         1     34
# 46         1     34
# 47         1     34
# 48         1     34
# 49         1     34
# 50         1     34
# 51         1     34
# 52         2     22
# 53         2     22
# 54         2     22
# 55         2     22
# 56         2     22
# 57         2     22
# 58         2     22
# 59         2     22
# 60         2     22
# 61         2     22
# 62         2     22
# 63         2     22
# 64         2     22
# 65         2     22
# 66         2     22
# 67         2     22
# 68         2     22
# 69         2     22
# 70         3     17
# 71         3     17
# 72         3     17
# 73         3     17
# 74         3     17
# 75         3     17
# 76         3     17
# 77         3     17
# 78         3     17
# 79         3     17
# 80         3     17
# 81         3     17
# 82         3     17
# 83         3     17
# 84         3     17
# 85         3     17
# 86         3     17
# 87         3     17
# 88         3     17
# 89         3     17
# 90         3     17
# 91         3     17
# 92         3     17
# 93         3     17
# 94         3     17
# 95         3     17
# 96         3     17
# 97         3     17
# 98         3     17
# 99         3     17
# 100        3     17
# 101        4     19
# 102        4     19
# 103        4     19
# 104        4     19
# 105        4     19
# 106        4     19
# 107        4     19
# 108        4     19
# 109        4     19
# 110        4     19
# 111        4     19
# 112        4     19
# 113        4     19
# 114        4     19
# 115        4     19
# 116        4     19
# 117        4     19
# 118        4     19
# 119        4     19
# 120        4     19
# 121        4     19
# 122        4     19
# 123        4     19
# 124        4     19
# 125        4     19
# 126        4     19
# 127        4     19
# 128        5      6
# 129        5      6
# 130        5      6
# 131        5      6
# 132        5      6
# 133        5      6
# 134        5      6
# 135        5      6
# 136        5      6
# 137        5      6
# 138        5      6
# 139        5      6
# 140        5      6
# 141        5      6
# 142        5      6
# 143        5      6
# 144        5      6
# 145        5      6
# 146        5      6
# 147        5      6
# 148        5      6
# 149        5      6
# 150        5      6
# 151        6     28
# 152        6     28
# 153        6     28
# 154        6     28
# 155        6     28
# 156        6     28
# 157        6     28
# 158        6     28
# 159        6     28
# 160        6     28
# 161        6     28
# 162        6     28
# 163        6     28
# 164        6     28
# 165        6     28
# 166        6     28
# 167        6     28
# 168        6     28
# 169        6     28
# 170        6     28
# 171        7     23
# 172        7     23
# 173        7     23
# 174        7     23
# 175        7     23
# 176        7     23
# 177        7     23
# 178        7     23
# 179        7     23
# 180        7     23
# 181        7     23
# 182        7     23
# 183        7     23
# 184        7     23
# 185        7     23
# 186        8      1
# 187        8      1
# 188        8      1
# 189        8      1
# 190        8      1
# 191        8      1
# 192        8      1
# 193        8      1
# 194        8      1
# 195        8      1
# 196        8      1
# 197        8      1
# 198        8      1
# 199        8      1

# %% [markdown]
# # old (parent) nb

# %%
""" 
COLLECT THE ONSET TR OF EVERY VIDEO ACROSS ALL SUBJECTS IN A LONG DATAFRAME
"""
vid_strL = ['vid1a','vid1b','vid2','vid3','vid4','vid5',
           'vid1a_q','vid1b_q','vid2_q','vid3_q','vid4_q','vid5_q']

timing_df_row_L = []
for sub_num in ALL_SUB_NS:
  ## read dataframe
  df = read_logfile(sub_num)
  df = reindex_and_TR_column(df)
  ## loop over video strings, extract onset TRs
  for vid_str in vid_strL:
    print('sub',sub_num,vid_str)
    ## extract onset TR for wedding string
    TR_vals = df[df.logdata == '%s: autoDraw = True'%vid_str].TR.values
    if vid_str[-2:]=='_q':
      timing_df_row = pd.DataFrame.from_dict({
        'sub_num':np.repeat(sub_num,2),
        'vid_str':np.repeat(vid_str,2),
        'wed_num':[0,11],
        'onset_TR':TR_vals
      })
    else:
      timing_df_row = pd.DataFrame.from_dict({
        'sub_num':np.repeat(sub_num,10),
        'vid_str':np.repeat(vid_str,10),
        'wed_num':np.arange(1,11),
        'onset_TR':TR_vals
      })
    timing_df_row_L.append(timing_df_row)
    
timing_df_cat = pd.concat(timing_df_row_L)
timing_df_cat.iloc[:200]
# Out:
# sub 3 vid1a
# sub 3 vid1b
# sub 3 vid2
# sub 3 vid3
# sub 3 vid4
# sub 3 vid5
# sub 3 vid1a_q
# sub 3 vid1b_q
# sub 3 vid2_q
# sub 3 vid3_q
# sub 3 vid4_q
# sub 3 vid5_q
# sub 4 vid1a
# sub 4 vid1b
# sub 4 vid2
# sub 4 vid3
# sub 4 vid4
# sub 4 vid5
# sub 4 vid1a_q
# sub 4 vid1b_q
# sub 4 vid2_q
# sub 4 vid3_q
# sub 4 vid4_q
# sub 4 vid5_q
# sub 5 vid1a
# sub 5 vid1b
# sub 5 vid2
# sub 5 vid3
# sub 5 vid4
# sub 5 vid5
# sub 5 vid1a_q
# sub 5 vid1b_q
# sub 5 vid2_q
# sub 5 vid3_q
# sub 5 vid4_q
# sub 5 vid5_q
# sub 6 vid1a
# sub 6 vid1b
# sub 6 vid2
# sub 6 vid3
# sub 6 vid4
# sub 6 vid5
# sub 6 vid1a_q
# sub 6 vid1b_q
# sub 6 vid2_q
# sub 6 vid3_q
# sub 6 vid4_q
# sub 6 vid5_q
# sub 7 vid1a
# sub 7 vid1b
# sub 7 vid2
# sub 7 vid3
# sub 7 vid4
# sub 7 vid5
# sub 7 vid1a_q
# sub 7 vid1b_q
# sub 7 vid2_q
# sub 7 vid3_q
# sub 7 vid4_q
# sub 7 vid5_q
# sub 8 vid1a
# sub 8 vid1b
# sub 8 vid2
# sub 8 vid3
# sub 8 vid4
# sub 8 vid5
# sub 8 vid1a_q
# sub 8 vid1b_q
# sub 8 vid2_q
# sub 8 vid3_q
# sub 8 vid4_q
# sub 8 vid5_q
# sub 9 vid1a
# sub 9 vid1b
# sub 9 vid2
# sub 9 vid3
# sub 9 vid4
# sub 9 vid5
# sub 9 vid1a_q
# sub 9 vid1b_q
# sub 9 vid2_q
# sub 9 vid3_q
# sub 9 vid4_q
# sub 9 vid5_q
# sub 10 vid1a
# sub 10 vid1b
# sub 10 vid2
# sub 10 vid3
# sub 10 vid4
# sub 10 vid5
# sub 10 vid1a_q
# sub 10 vid1b_q
# sub 10 vid2_q
# sub 10 vid3_q
# sub 10 vid4_q
# sub 10 vid5_q
# sub 12 vid1a
# sub 12 vid1b
# sub 12 vid2
# sub 12 vid3
# sub 12 vid4
# sub 12 vid5
# sub 12 vid1a_q
# sub 12 vid1b_q
# sub 12 vid2_q
# sub 12 vid3_q
# sub 12 vid4_q
# sub 12 vid5_q
# sub 13 vid1a
# sub 13 vid1b
# sub 13 vid2
# sub 13 vid3
# sub 13 vid4
# sub 13 vid5
# sub 13 vid1a_q
# sub 13 vid1b_q
# sub 13 vid2_q
# sub 13 vid3_q
# sub 13 vid4_q
# sub 13 vid5_q
# sub 14 vid1a
# sub 14 vid1b
# sub 14 vid2
# sub 14 vid3
# sub 14 vid4
# sub 14 vid5
# sub 14 vid1a_q
# sub 14 vid1b_q
# sub 14 vid2_q
# sub 14 vid3_q
# sub 14 vid4_q
# sub 14 vid5_q
# sub 15 vid1a
# sub 15 vid1b
# sub 15 vid2
# sub 15 vid3
# sub 15 vid4
# sub 15 vid5
# sub 15 vid1a_q
# sub 15 vid1b_q
# sub 15 vid2_q
# sub 15 vid3_q
# sub 15 vid4_q
# sub 15 vid5_q
# sub 17 vid1a
# sub 17 vid1b
# sub 17 vid2
# sub 17 vid3
# sub 17 vid4
# sub 17 vid5
# sub 17 vid1a_q
# sub 17 vid1b_q
# sub 17 vid2_q
# sub 17 vid3_q
# sub 17 vid4_q
# sub 17 vid5_q
# sub 18 vid1a
# sub 18 vid1b
# sub 18 vid2
# sub 18 vid3
# sub 18 vid4
# sub 18 vid5
# sub 18 vid1a_q
# sub 18 vid1b_q
# sub 18 vid2_q
# sub 18 vid3_q
# sub 18 vid4_q
# sub 18 vid5_q
# sub 19 vid1a
# sub 19 vid1b
# sub 19 vid2
# sub 19 vid3
# sub 19 vid4
# sub 19 vid5
# sub 19 vid1a_q
# sub 19 vid1b_q
# sub 19 vid2_q
# sub 19 vid3_q
# sub 19 vid4_q
# sub 19 vid5_q
# sub 22 vid1a
# sub 22 vid1b
# sub 22 vid2
# sub 22 vid3
# sub 22 vid4
# sub 22 vid5
# sub 22 vid1a_q
# sub 22 vid1b_q
# sub 22 vid2_q
# sub 22 vid3_q
# sub 22 vid4_q
# sub 22 vid5_q
# sub 23 vid1a
# sub 23 vid1b
# sub 23 vid2
# sub 23 vid3
# sub 23 vid4
# sub 23 vid5
# sub 23 vid1a_q
# sub 23 vid1b_q
# sub 23 vid2_q
# sub 23 vid3_q
# sub 23 vid4_q
# sub 23 vid5_q
# sub 24 vid1a
# sub 24 vid1b
# sub 24 vid2
# sub 24 vid3
# sub 24 vid4
# sub 24 vid5
# sub 24 vid1a_q
# sub 24 vid1b_q
# sub 24 vid2_q
# sub 24 vid3_q
# sub 24 vid4_q
# sub 24 vid5_q
# sub 25 vid1a
# sub 25 vid1b
# sub 25 vid2
# sub 25 vid3
# sub 25 vid4
# sub 25 vid5
# sub 25 vid1a_q
# sub 25 vid1b_q
# sub 25 vid2_q
# sub 25 vid3_q
# sub 25 vid4_q
# sub 25 vid5_q
# sub 26 vid1a
# sub 26 vid1b
# sub 26 vid2
# sub 26 vid3
# sub 26 vid4
# sub 26 vid5
# sub 26 vid1a_q
# sub 26 vid1b_q
# sub 26 vid2_q
# sub 26 vid3_q
# sub 26 vid4_q
# sub 26 vid5_q
# sub 27 vid1a
# sub 27 vid1b
# sub 27 vid2
# sub 27 vid3
# sub 27 vid4
# sub 27 vid5
# sub 27 vid1a_q
# sub 27 vid1b_q
# sub 27 vid2_q
# sub 27 vid3_q
# sub 27 vid4_q
# sub 27 vid5_q
# sub 28 vid1a
# sub 28 vid1b
# sub 28 vid2
# sub 28 vid3
# sub 28 vid4
# sub 28 vid5
# sub 28 vid1a_q
# sub 28 vid1b_q
# sub 28 vid2_q
# sub 28 vid3_q
# sub 28 vid4_q
# sub 28 vid5_q
# sub 29 vid1a
# sub 29 vid1b
# sub 29 vid2
# sub 29 vid3
# sub 29 vid4
# sub 29 vid5
# sub 29 vid1a_q
# sub 29 vid1b_q
# sub 29 vid2_q
# sub 29 vid3_q
# sub 29 vid4_q
# sub 29 vid5_q
# sub 30 vid1a
# sub 30 vid1b
# sub 30 vid2
# sub 30 vid3
# sub 30 vid4
# sub 30 vid5
# sub 30 vid1a_q
# sub 30 vid1b_q
# sub 30 vid2_q
# sub 30 vid3_q
# sub 30 vid4_q
# sub 30 vid5_q
# sub 31 vid1a
# sub 31 vid1b
# sub 31 vid2
# sub 31 vid3
# sub 31 vid4
# sub 31 vid5
# sub 31 vid1a_q
# sub 31 vid1b_q
# sub 31 vid2_q
# sub 31 vid3_q
# sub 31 vid4_q
# sub 31 vid5_q
# sub 32 vid1a
# sub 32 vid1b
# sub 32 vid2
# sub 32 vid3
# sub 32 vid4
# sub 32 vid5
# sub 32 vid1a_q
# sub 32 vid1b_q
# sub 32 vid2_q
# sub 32 vid3_q
# sub 32 vid4_q
# sub 32 vid5_q
# sub 33 vid1a
# sub 33 vid1b
# sub 33 vid2
# sub 33 vid3
# sub 33 vid4
# sub 33 vid5
# sub 33 vid1a_q
# sub 33 vid1b_q
# sub 33 vid2_q
# sub 33 vid3_q
# sub 33 vid4_q
# sub 33 vid5_q
# sub 34 vid1a
# sub 34 vid1b
# sub 34 vid2
# sub 34 vid3
# sub 34 vid4
# sub 34 vid5
# sub 34 vid1a_q
# sub 34 vid1b_q
# sub 34 vid2_q
# sub 34 vid3_q
# sub 34 vid4_q
# sub 34 vid5_q
# sub 35 vid1a
# sub 35 vid1b
# sub 35 vid2
# sub 35 vid3
# sub 35 vid4
# sub 35 vid5
# sub 35 vid1a_q
# sub 35 vid1b_q
# sub 35 vid2_q
# sub 35 vid3_q
# sub 35 vid4_q
# sub 35 vid5_q
# sub 36 vid1a
# sub 36 vid1b
# sub 36 vid2
# sub 36 vid3
# sub 36 vid4
# sub 36 vid5
# sub 36 vid1a_q
# sub 36 vid1b_q
# sub 36 vid2_q
# sub 36 vid3_q
# sub 36 vid4_q
# sub 36 vid5_q
# sub 37 vid1a
# sub 37 vid1b
# sub 37 vid2
# sub 37 vid3
# sub 37 vid4
# sub 37 vid5
# sub 37 vid1a_q
# sub 37 vid1b_q
# sub 37 vid2_q
# sub 37 vid3_q
# sub 37 vid4_q
# sub 37 vid5_q
# sub 38 vid1a
# sub 38 vid1b
# sub 38 vid2
# sub 38 vid3
# sub 38 vid4
# sub 38 vid5
# sub 38 vid1a_q
# sub 38 vid1b_q
# sub 38 vid2_q
# sub 38 vid3_q
# sub 38 vid4_q
# sub 38 vid5_q
# sub 40 vid1a
# sub 40 vid1b
# sub 40 vid2
# sub 40 vid3
# sub 40 vid4
# sub 40 vid5
# sub 40 vid1a_q
# sub 40 vid1b_q
# sub 40 vid2_q
# sub 40 vid3_q
# sub 40 vid4_q
# sub 40 vid5_q
# sub 41 vid1a
# sub 41 vid1b
# sub 41 vid2
# sub 41 vid3
# sub 41 vid4
# sub 41 vid5
# sub 41 vid1a_q
# sub 41 vid1b_q
# sub 41 vid2_q
# sub 41 vid3_q
# sub 41 vid4_q
# sub 41 vid5_q
# sub 42 vid1a
# sub 42 vid1b
# sub 42 vid2
# sub 42 vid3
# sub 42 vid4
# sub 42 vid5
# sub 42 vid1a_q
# sub 42 vid1b_q
# sub 42 vid2_q
# sub 42 vid3_q
# sub 42 vid4_q
# sub 42 vid5_q
# sub 43 vid1a
# sub 43 vid1b
# sub 43 vid2
# sub 43 vid3
# sub 43 vid4
# sub 43 vid5
# sub 43 vid1a_q
# sub 43 vid1b_q
# sub 43 vid2_q
# sub 43 vid3_q
# sub 43 vid4_q
# sub 43 vid5_q
# sub 44 vid1a
# sub 44 vid1b
# sub 44 vid2
# sub 44 vid3
# sub 44 vid4
# sub 44 vid5
# sub 44 vid1a_q
# sub 44 vid1b_q
# sub 44 vid2_q
# sub 44 vid3_q
# sub 44 vid4_q
# sub 44 vid5_q
#    sub_num  vid_str  wedding_num  onset_TR
# 0        3    vid1a            1       108
# 1        3    vid1a            2       204
# 2        3    vid1a            3       300
# 3        3    vid1a            4       396
# 4        3    vid1a            5       492
# 5        3    vid1a            6       588
# 6        3    vid1a            7       684
# 7        3    vid1a            8       781
# 8        3    vid1a            9       877
# 9        3    vid1a           10       973
# 0        3    vid1b            1       125
# 1        3    vid1b            2       221
# 2        3    vid1b            3       317
# 3        3    vid1b            4       413
# 4        3    vid1b            5       509
# 5        3    vid1b            6       605
# 6        3    vid1b            7       701
# 7        3    vid1b            8       797
# 8        3    vid1b            9       893
# 9        3    vid1b           10       990
# 0        3     vid2            1       131
# 1        3     vid2            2       227
# 2        3     vid2            3       323
# 3        3     vid2            4       419
# 4        3     vid2            5       515
# 5        3     vid2            6       611
# 6        3     vid2            7       707
# 7        3     vid2            8       803
# 8        3     vid2            9       899
# 9        3     vid2           10       996
# 0        3     vid3            1       142
# 1        3     vid3            2       238
# 2        3     vid3            3       334
# 3        3     vid3            4       430
# 4        3     vid3            5       526
# 5        3     vid3            6       622
# 6        3     vid3            7       718
# 7        3     vid3            8       815
# 8        3     vid3            9       911
# 9        3     vid3           10      1007
# 0        3     vid4            1       157
# 1        3     vid4            2       254
# 2        3     vid4            3       350
# 3        3     vid4            4       446
# 4        3     vid4            5       542
# 5        3     vid4            6       638
# 6        3     vid4            7       734
# 7        3     vid4            8       830
# 8        3     vid4            9       926
# 9        3     vid4           10      1022
# 0        3     vid5            1       173
# 1        3     vid5            2       270
# 2        3     vid5            3       366
# 3        3     vid5            4       462
# 4        3     vid5            5       558
# 5        3     vid5            6       654
# 6        3     vid5            7       750
# 7        3     vid5            8       846
# 8        3     vid5            9       942
# 9        3     vid5           10      1038
# 0        3  vid1a_q            0         9
# 1        3  vid1a_q           11      1072
# 0        3  vid1b_q            0        26
# 1        3  vid1b_q           11      1089
# 0        3   vid2_q            0        32
# 1        3   vid2_q           11      1095
# 0        3   vid3_q            0        46
# 1        3   vid3_q           11      1109
# 0        3   vid4_q            0        64
# 1        3   vid4_q           11      1127
# 0        3   vid5_q            0        80
# 1        3   vid5_q           11      1143
# 0        4    vid1a            1       109
# 1        4    vid1a            2       204
# 2        4    vid1a            3       300
# 3        4    vid1a            4       396
# 4        4    vid1a            5       492
# 5        4    vid1a            6       589
# 6        4    vid1a            7       684
# 7        4    vid1a            8       780
# 8        4    vid1a            9       876
# 9        4    vid1a           10       973
# 0        4    vid1b            1       125
# 1        4    vid1b            2       221
# 2        4    vid1b            3       317
# 3        4    vid1b            4       413
# 4        4    vid1b            5       509
# 5        4    vid1b            6       605
# 6        4    vid1b            7       701
# 7        4    vid1b            8       797
# 8        4    vid1b            9       893
# 9        4    vid1b           10       989
# 0        4     vid2            1       131
# 1        4     vid2            2       227
# 2        4     vid2            3       323
# 3        4     vid2            4       419
# 4        4     vid2            5       515
# 5        4     vid2            6       611
# 6        4     vid2            7       707
# 7        4     vid2            8       803
# 8        4     vid2            9       899
# 9        4     vid2           10       995
# 0        4     vid3            1       143
# 1        4     vid3            2       238
# 2        4     vid3            3       334
# 3        4     vid3            4       430
# 4        4     vid3            5       527
# 5        4     vid3            6       623
# 6        4     vid3            7       719
# 7        4     vid3            8       814
# 8        4     vid3            9       910
# 9        4     vid3           10      1007
# 0        4     vid4            1       158
# 1        4     vid4            2       254
# 2        4     vid4            3       349
# 3        4     vid4            4       446
# 4        4     vid4            5       542
# 5        4     vid4            6       638
# 6        4     vid4            7       734
# 7        4     vid4            8       829
# 8        4     vid4            9       926
# 9        4     vid4           10      1022
# 0        4     vid5            1       174
# 1        4     vid5            2       270
# 2        4     vid5            3       365
# 3        4     vid5            4       462
# 4        4     vid5            5       558
# 5        4     vid5            6       654
# 6        4     vid5            7       750
# 7        4     vid5            8       845
# 8        4     vid5            9       942
# 9        4     vid5           10      1038
# 0        4  vid1a_q            0         9
# 1        4  vid1a_q           11      1071
# 0        4  vid1b_q            0        26
# 1        4  vid1b_q           11      1088
# 0        4   vid2_q            0        32
# 1        4   vid2_q           11      1094
# 0        4   vid3_q            0        46
# 1        4   vid3_q           11      1108
# 0        4   vid4_q            0        64
# 1        4   vid4_q           11      1126
# 0        4   vid5_q            0        80
# 1        4   vid5_q           11      1142
# 0        5    vid1a            1       109
# 1        5    vid1a            2       204
# 2        5    vid1a            3       300
# 3        5    vid1a            4       396
# 4        5    vid1a            5       493
# 5        5    vid1a            6       589
# 6        5    vid1a            7       685
# 7        5    vid1a            8       781
# 8        5    vid1a            9       877
# 9        5    vid1a           10       973
# 0        5    vid1b            1       125
# 1        5    vid1b            2       221
# 2        5    vid1b            3       317
# 3        5    vid1b            4       413
# 4        5    vid1b            5       509
# 5        5    vid1b            6       605
# 6        5    vid1b            7       701
# 7        5    vid1b            8       797
# 8        5    vid1b            9       894
# 9        5    vid1b           10       990
# 0        5     vid2            1       131
# 1        5     vid2            2       227
# 2        5     vid2            3       323
# 3        5     vid2            4       419
# 4        5     vid2            5       515
# 5        5     vid2            6       611
# 6        5     vid2            7       707
# 7        5     vid2            8       803
# 8        5     vid2            9       900
# 9        5     vid2           10       996
# 0        5     vid3            1       143
# 1        5     vid3            2       239
# 2        5     vid3            3       335
# 3        5     vid3            4       430
# 4        5     vid3            5       527
# 5        5     vid3            6       623
# 6        5     vid3            7       719
# 7        5     vid3            8       815
# 8        5     vid3            9       911
# 9        5     vid3           10      1008
# 0        5     vid4            1       158
# 1        5     vid4            2       254
# 2        5     vid4            3       350
# 3        5     vid4            4       446
# 4        5     vid4            5       542
# 5        5     vid4            6       638
# 6        5     vid4            7       734
# 7        5     vid4            8       830
# 8        5     vid4            9       926
# 9        5     vid4           10      1023
# 0        5     vid5            1       174
# 1        5     vid5            2       270
# 2        5     vid5            3       366
# 3        5     vid5            4       462
# 4        5     vid5            5       558
# 5        5     vid5            6       654

# %%
""" 
TAKE THE MEAN ACROSS SUBJECTS TO GET A DATAFRAME WITH A TR VALUE FOR EACH VIDEO OF EACH WEDDING
"""
timing_df = timing_df_cat.groupby(['wed_num','vid_str']).mean()
timing_df = timing_df.apply(np.floor).astype(int)
timing_df = timing_df.reset_index()
timing_df = timing_df.drop('sub_num',axis=1)

# %%
""" SHIFTING TO ACOUNT FOR HEMODYNAMIC LAG"""
timing_df.onset_TR = timing_df.onset_TR + 3

# %%
timing_df.iloc[:200]
# Out:
#     wedding_num  vid_str  onset_TR
# 0             0  vid1a_q        12
# 1             0  vid1b_q        29
# 2             0   vid2_q        35
# 3             0   vid3_q        49
# 4             0   vid4_q        67
# 5             0   vid5_q        83
# 6             1    vid1a       111
# 7             1    vid1b       128
# 8             1     vid2       134
# 9             1     vid3       145
# 10            1     vid4       160
# 11            1     vid5       176
# 12            2    vid1a       207
# 13            2    vid1b       224
# 14            2     vid2       230
# 15            2     vid3       241
# 16            2     vid4       256
# 17            2     vid5       272
# 18            3    vid1a       303
# 19            3    vid1b       319
# 20            3     vid2       325
# 21            3     vid3       337
# 22            3     vid4       352
# 23            3     vid5       368
# 24            4    vid1a       398
# 25            4    vid1b       415
# 26            4     vid2       421
# 27            4     vid3       433
# 28            4     vid4       448
# 29            4     vid5       464
# 30            5    vid1a       495
# 31            5    vid1b       511
# 32            5     vid2       517
# 33            5     vid3       529
# 34            5     vid4       544
# 35            5     vid5       560
# 36            6    vid1a       591
# 37            6    vid1b       608
# 38            6     vid2       614
# 39            6     vid3       625
# 40            6     vid4       640
# 41            6     vid5       656
# 42            7    vid1a       687
# 43            7    vid1b       704
# 44            7     vid2       710
# 45            7     vid3       721
# 46            7     vid4       736
# 47            7     vid5       752
# 48            8    vid1a       783
# 49            8    vid1b       800
# 50            8     vid2       806
# 51            8     vid3       817
# 52            8     vid4       833
# 53            8     vid5       849
# 54            9    vid1a       879
# 55            9    vid1b       896
# 56            9     vid2       902
# 57            9     vid3       914
# 58            9     vid4       929
# 59            9     vid5       945
# 60           10    vid1a       976
# 61           10    vid1b       993
# 62           10     vid2       999
# 63           10     vid3      1010
# 64           10     vid4      1025
# 65           10     vid5      1041
# 66           11  vid1a_q      1074
# 67           11  vid1b_q      1091
# 68           11   vid2_q      1097
# 69           11   vid3_q      1111
# 70           11   vid4_q      1129
# 71           11   vid5_q      1145

# %% [markdown]
# # include offset

# %%
"""
the first 26 seconds are intro, followed by 9 seconds start-event, 
17 seconds campfire or flower (depending on label in pkl), 
23 seconds coin or torch, 24 seconds egg or painting, and remainder gifts. 
"""

## NB CURRENTLY USING 10S AS PLACEHOLDER FOR FINAL EVENT 
TR_rate = 1.5
vid_len_D = {'vid1a':26/TR_rate,'vid1b':9/TR_rate,'vid2':17/TR_rate,
             'vid3':23/TR_rate,'vid4':24/TR_rate,'vid5':10/TR_rate,
             'vid1a_q':26/TR_rate,'vid1b_q':9/TR_rate,'vid2_q':17/TR_rate,
             'vid3_q':23/TR_rate,'vid4_q':24/TR_rate,'vid5_q':10/TR_rate
            }
vid_len_D = {k:np.round(v).astype(int) for k,v in vid_len_D.items()}
vid_len_D
# Out:
# {'vid1a': 17,
#  'vid1b': 6,
#  'vid2': 11,
#  'vid3': 15,
#  'vid4': 16,
#  'vid5': 7,
#  'vid1a_q': 17,
#  'vid1b_q': 6,
#  'vid2_q': 11,
#  'vid3_q': 15,
#  'vid4_q': 16,
#  'vid5_q': 7}

# %%
for vid_str,num_TRs in vid_len_D.items():
  timing_df.loc[timing_df['vid_str']==vid_str,'len_TRs'] = num_TRs
timing_df['offset_TR'] = timing_df['onset_TR'] + timing_df['len_TRs']

# %%
timing_df = timing_df.astype({'onset_TR':int,'len_TRs':int,'offset_TR':int})

# %%
timing_df.to_csv('exp_timing.csv')
