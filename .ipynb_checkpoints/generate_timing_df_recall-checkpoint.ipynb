# %% [markdown]
# * creates `deriv/timing_df_recall.csv`
# - make and save a dataframe containing onset and offset TRs for each cue presentation during recall

# %%
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt

import sklearn
import brainiak
import nilearn as nl
from nilearn import image, plotting, input_data

from scipy.spatial import distance

pd.options.display.max_rows = 200

# %% [markdown]
# - [SUB]_recall.log does not exist for all sub
# - use [sub]_recall_mylog.log instead

# %% [markdown]
# ### cols
# - sub_num
# - wed_id
# - onset TR
# - offset TR

# %%
# def read_logfile(sub_num):

sub_num = 12
fpath = 'data/behav/silvy_buckets/sub%.2iday2/%i_recall_mylog.log'%(100+sub_num,sub_num)
f = open(fpath, "r")
first_line = f.readline()


sub_df = pd.DataFrame(columns=['sub_num','wed_id','onset_TR','offset_TR'])

first_tstamp = float(first_line.split()[1])

for x in f:
  print('0',x)
  RV,tstamp,stim = x.split(' ')
  wed_id = stim.split('/')[-1].split('.')[0][1:]
# Out:
# 0 RV0.7: 27.403, stimsday2details/C23.png
#
# RV0.7: 0 23
# 0 RV1.4: 51.188, stimsday2details/C19.png
#
# RV1.4: 0 19
# 0 RV2.2: 80.281, stimsday2details/C6.png
#
# RV2.2: 0 6
# 0 RV3.0: 120.887, stimsday2details/C1.png
#
# RV3.0: 0 1
# 0 RV4.5: 160.851, stimsday2details/C20.png
#
# RV4.5: 0 20
# 0 RV5.10: 205.285, stimsday2details/C34.png
#
# RV5.10: 0 34
# 0 RV6.11: 252.051, stimsday2details/C38.png
#
# RV6.11: 0 38
# 0 RV7.9: 308.846, stimsday2details/C29.png
#
# RV7.9: 0 29
# 0 RV8.1: 362.356, stimsday2details/C2.png
#
# RV8.1: 0 2
# 0 RV9.8: 452.136, stimsday2details/C28.png
#
# RV9.8: 0 28
# 0 RV10.3: 549.192, stimsday2details/C17.png
#
# RV10.3: 0 17
# 0 RV11.6: 599.389, stimsday2details/C22.png
#
# RV11.6: 0 22

# %%
def read_logfile(sub_num,task='recall'):
  """ 
  read psychopy logifle into dataframe
  """
  # initialize dataframe
  df = pd.DataFrame(columns=['tstamp','logdata'])
  df = df.astype({'tstamp':float})
  # open logfile
  fpath = 'data/behav/silvy_buckets/sub%iday2/%i_%s.log'%(100+sub_num,sub_num,task)
  f = open(fpath, "r")
  # loop over logfile rows
  for x in f:
    tstamp,B,C = x.split('\t')
    tstamp = float(tstamp)
#     df.loc[tstamp,'logtype'] = B[:-1]
    df.loc[tstamp,'logdata'] = C[:-1]
    df.loc[tstamp,'tstamp'] = tstamp
  return df

def reindex_and_TR_column(df):
  TR_rate = 1.5
  # first TR
  first_TR_tstamp = df[df.logdata=='Keypress: equal'].iloc[0].tstamp
  # center tstamps on first TR
  df.tstamp = df.tstamp-first_TR_tstamp
  # include TR column
  df['TR'] = np.ceil(df.tstamp/TR_rate)
  df = df.astype({'TR':int})
  # remove negative TRs
  df = df[df.TR>-1]
  # reindex by row number
  df.index = np.arange(len(df))
  return df

def include_wed_cols(df):
  ''' includes columns with wed_num and wed_id 
  '''
  df.loc[:,'wed_num'] = 99
  df.loc[:,'wed_id'] = 99
  wed_start_idx = df[df.logdata.str[:len("New trial")]=="New trial"].index
  wed_id_series = df.iloc[wed_start_idx].logdata.str.split('/').str[-1].str.split('.').str[0].str[1:]
  for wed_num,(t0,t1,wed_id) in enumerate(zip(wed_start_idx[:-1],wed_start_idx[1:],wed_id_series)):
    df.loc[t0:t1,'wed_num']=wed_num
    df.loc[t0:t1,'wed_id']=wed_id
  df.loc[wed_start_idx[-1]:,'wed_num']=11
  df.loc[wed_start_idx[-1]:,'wed_id']=wed_id_series.iloc[-1]
  return df

# %%
for sub_n in range(30,35):
  df = read_logfile(sub_n)
  df = reindex_and_TR_column(df)
  df = include_wed_cols(df)
  print(df.shape)
  df.iloc[:200]
# Out:
# (392, 5)
# (294, 5)
# (249, 5)
# (562, 5)
# (546, 5)

# %%
sub_n=23
df = read_logfile(sub_n)
df = reindex_and_TR_column(df)
df = include_wed_cols(df)
print(df.shape)
df.iloc[:200]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-9f434517a88d> in <module>
#       1 sub_n=23
# ----> 2 df = read_logfile(sub_n)
#       3 df = reindex_and_TR_column(df)
#       4 df = include_wed_cols(df)
#       5 print(df.shape)
#
# <ipython-input-3-47fd8f383fda> in read_logfile(sub_num, task)
#       8   # open logfile
#       9   fpath = 'data/behav/silvy_buckets/sub%iday2/%i_%s.log'%(100+sub_num,sub_num,task)
# ---> 10   f = open(fpath, "r")
#      11   # loop over logfile rows
#      12   for x in f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/behav/silvy_buckets/sub123day2/23_recall.log'

# %%
read_logfile(32,task='recall').iloc[:200]
# Out:
#             tstamp                                            logdata
# 1.8353      1.8353  Import Error: No module named 'psychtoolbox'. ...
# 4.8882      4.8882  User requested fullscreen with size [2560 1440...
# 5.5324      5.5324              window1: recordFrameIntervals = False
# 5.6983      5.6983               window1: recordFrameIntervals = True
# 5.8818      5.8818              window1: recordFrameIntervals = False
# 6.0052      6.0052  Created text_2 = TextStim(__class__=<class 'ps...
# 6.0140      6.0140  Created waiting = TextStim(__class__=<class 'p...
# 6.0206      6.0206  Created cueImage = ImageStim(__class__=<class ...
# 6.0540      6.0540  Created text = TextStim(__class__=<class 'psyc...
# 6.0993      6.0993                            text_2: autoDraw = True
# 6.4185      6.4185                                        Keypress: g
# 6.4316      6.4316                           waiting: autoDraw = True
# 23.9507    23.9507                                    Keypress: equal
# 23.9617    23.9617  Imported recall.csv as conditions, 12 conditio...
# 23.9627    23.9627  Created sequence: random, trialTypes=12, nReps...
# 23.9631    23.9631  New trial (rep=0, index=0): OrderedDict([('cue...
# 23.9987    23.9987                              text: autoDraw = True
# 25.4502    25.4502                                    Keypress: equal
# 26.9497    26.9497                                    Keypress: equal
# 28.4497    28.4497                                    Keypress: equal
# 29.9497    29.9497                                    Keypress: equal
# 31.4496    31.4496                                    Keypress: equal
# 32.9507    32.9507                                    Keypress: equal
# 34.4508    34.4508                                    Keypress: equal
# 35.9497    35.9497                                    Keypress: equal
# 37.4501    37.4501                                    Keypress: equal
# 38.9506    38.9506                                    Keypress: equal
# 40.4496    40.4496                                    Keypress: equal
# 41.9541    41.9541                                    Keypress: equal
# 43.4507    43.4507                                    Keypress: equal
# 44.9498    44.9498                                    Keypress: equal
# 46.4537    46.4537                                    Keypress: equal
# 47.9541    47.9541                                    Keypress: equal
# 49.4536    49.4536                                    Keypress: equal
# 50.9503    50.9503                                    Keypress: equal
# 52.4535    52.4535                                    Keypress: equal
# 53.9549    53.9549                                    Keypress: equal
# 55.4393    55.4393                                    Keypress: equal
# 56.1042    56.1042                                    Keypress: space
# 56.2519    56.2519  New trial (rep=0, index=1): OrderedDict([('cue...
# 56.2810    56.2810                              text: autoDraw = True
# 56.9444    56.9444                                    Keypress: equal
# 58.4397    58.4397                                    Keypress: equal
# 59.9423    59.9423                                    Keypress: equal
# 61.4492    61.4492                                    Keypress: equal
# 62.9502    62.9502                                    Keypress: equal
# 64.4495    64.4495                                    Keypress: equal
# 65.9489    65.9489                                    Keypress: equal
# 67.4492    67.4492                                    Keypress: equal
# 68.9496    68.9496                                    Keypress: equal
# 70.4491    70.4491                                    Keypress: equal
# 71.9529    71.9529                                    Keypress: equal
# 73.4536    73.4536                                    Keypress: equal
# 74.9547    74.9547                                    Keypress: equal
# 76.4541    76.4541                                    Keypress: equal
# 77.9497    77.9497                                    Keypress: equal
# 79.4549    79.4549                                    Keypress: equal
# 80.9499    80.9499                                    Keypress: equal
# 82.4537    82.4537                                    Keypress: equal
# 83.9540    83.9540                                    Keypress: equal
# 85.4534    85.4534                                    Keypress: equal
# 85.8035    85.8035                                    Keypress: space
# 85.9491    85.9491  New trial (rep=0, index=2): OrderedDict([('cue...
# 85.9642    85.9642                              text: autoDraw = True
# 86.9532    86.9532                                    Keypress: equal
# 88.4539    88.4539                                    Keypress: equal
# 89.9540    89.9540                                    Keypress: equal
# 91.4536    91.4536                                    Keypress: equal
# 92.9527    92.9527                                    Keypress: equal
# 94.4540    94.4540                                    Keypress: equal
# 95.9485    95.9485                                    Keypress: equal
# 97.4485    97.4485                                    Keypress: equal
# 98.9486    98.9486                                    Keypress: equal
# 100.4486  100.4486                                    Keypress: equal
# 101.9379  101.9379                                    Keypress: equal
# 103.4487  103.4487                                    Keypress: equal
# 104.9492  104.9492                                    Keypress: equal
# 106.4484  106.4484                                    Keypress: equal
# 107.9375  107.9375                                    Keypress: equal
# 109.4542  109.4542                                    Keypress: equal
# 110.9485  110.9485                                    Keypress: equal
# 112.4378  112.4378                                    Keypress: equal
# 113.9383  113.9383                                    Keypress: equal
# 114.2321  114.2321                                    Keypress: space
# 114.3769  114.3769  New trial (rep=0, index=3): OrderedDict([('cue...
# 114.3976  114.3976                              text: autoDraw = True
# 115.4381  115.4381                                    Keypress: equal
# 116.9376  116.9376                                    Keypress: equal
# 118.4378  118.4378                                    Keypress: equal
# 119.9382  119.9382                                    Keypress: equal
# 121.4394  121.4394                                    Keypress: equal
# 122.9383  122.9383                                    Keypress: equal
# 124.4539  124.4539                                    Keypress: equal
# 125.9481  125.9481                                    Keypress: equal
# 127.4484  127.4484                                    Keypress: equal
# 128.9482  128.9482                                    Keypress: equal
# 130.4528  130.4528                                    Keypress: equal
# 131.9488  131.9488                                    Keypress: equal
# 133.4494  133.4494                                    Keypress: equal
# 134.9531  134.9531                                    Keypress: equal
# 136.4365  136.4365                                    Keypress: equal
# 137.9364  137.9364                                    Keypress: equal
# 139.4096  139.4096                                    Keypress: space
# 139.5585  139.5585  New trial (rep=0, index=4): OrderedDict([('cue...
# 139.5685  139.5685                                    Keypress: equal
# 139.5805  139.5805                              text: autoDraw = True
# 140.9531  140.9531                                    Keypress: equal
# 142.4530  142.4530                                    Keypress: equal
# 143.9362  143.9362                                    Keypress: equal
# 145.4410  145.4410                                    Keypress: equal
# 146.9403  146.9403                                    Keypress: equal
# 148.4406  148.4406                                    Keypress: equal
# 149.9412  149.9412                                    Keypress: equal
# 151.4523  151.4523                                    Keypress: equal
# 152.9527  152.9527                                    Keypress: equal
# 154.4529  154.4529                                    Keypress: equal
# 155.9368  155.9368                                    Keypress: equal
# 157.4368  157.4368                                    Keypress: equal
# 158.9366  158.9366                                    Keypress: equal
# 160.4354  160.4354                                    Keypress: equal
# 161.9520  161.9520                                    Keypress: equal
# 163.4491  163.4491                                    Keypress: equal
# 164.9528  164.9528                                    Keypress: equal
# 166.4479  166.4479                                    Keypress: equal
# 167.9526  167.9526                                    Keypress: equal
# 169.4528  169.4528                                    Keypress: equal
# 170.9478  170.9478                                    Keypress: equal
# 172.4356  172.4356                                    Keypress: equal
# 173.9485  173.9485                                    Keypress: equal
# 175.4356  175.4356                                    Keypress: equal
# 176.9359  176.9359                                    Keypress: equal
# 178.4364  178.4364                                    Keypress: equal
# 178.7866  178.7866                                    Keypress: space
# 178.9352  178.9352  New trial (rep=0, index=5): OrderedDict([('cue...
# 178.9640  178.9640                              text: autoDraw = True
# 179.9476  179.9476                                    Keypress: equal
# 181.4361  181.4361                                    Keypress: equal
# 182.9361  182.9361                                    Keypress: equal
# 184.4359  184.4359                                    Keypress: equal
# 185.9351  185.9351                                    Keypress: equal
# 187.4352  187.4352                                    Keypress: equal
# 188.9359  188.9359                                    Keypress: equal
# 190.4361  190.4361                                    Keypress: equal
# 191.9355  191.9355                                    Keypress: equal
# 193.4361  193.4361                                    Keypress: equal
# 194.9363  194.9363                                    Keypress: equal
# 196.4355  196.4355                                    Keypress: equal
# 197.7649  197.7649                                    Keypress: space
# 197.9056  197.9056  New trial (rep=0, index=6): OrderedDict([('cue...
# 197.9293  197.9293                              text: autoDraw = True
# 197.9376  197.9376                                    Keypress: equal
# 199.4334  199.4334                                    Keypress: equal
# 200.9523  200.9523                                    Keypress: equal
# 202.4475  202.4475                                    Keypress: equal
# 203.9472  203.9472                                    Keypress: equal
# 205.4354  205.4354                                    Keypress: equal
# 206.9516  206.9516                                    Keypress: equal
# 208.4512  208.4512                                    Keypress: equal
# 209.9517  209.9517                                    Keypress: equal
# 211.4360  211.4360                                    Keypress: equal
# 212.9358  212.9358                                    Keypress: equal
# 214.4360  214.4360                                    Keypress: equal
# 215.9523  215.9523                                    Keypress: equal
# 217.4472  217.4472                                    Keypress: equal
# 218.9481  218.9481                                    Keypress: equal
# 219.9191  219.9191                                    Keypress: space
# 220.0538  220.0538  New trial (rep=0, index=7): OrderedDict([('cue...
# 220.0799  220.0799                              text: autoDraw = True
# 220.4470  220.4470                                    Keypress: equal
# 221.9472  221.9472                                    Keypress: equal
# 223.4334  223.4334                                    Keypress: equal
# 224.9330  224.9330                                    Keypress: equal
# 226.4322  226.4322                                    Keypress: equal
# 227.9334  227.9334                                    Keypress: equal
# 229.4323  229.4323                                    Keypress: equal
# 230.9403  230.9403                                    Keypress: equal
# 232.4396  232.4396                                    Keypress: equal
# 233.9398  233.9398                                    Keypress: equal
# 235.4402  235.4402                                    Keypress: equal
# 236.9345  236.9345                                    Keypress: equal
# 238.4329  238.4329                                    Keypress: equal
# 239.9342  239.9342                                    Keypress: equal
# 241.4348  241.4348                                    Keypress: equal
# 241.7638  241.7638                                    Keypress: space
# 241.9104  241.9104  New trial (rep=0, index=8): OrderedDict([('cue...
# 241.9297  241.9297                              text: autoDraw = True
# 242.9518  242.9518                                    Keypress: equal
# 244.4522  244.4522                                    Keypress: equal
# 245.9352  245.9352                                    Keypress: equal
# 247.4353  247.4353                                    Keypress: equal
# 248.9352  248.9352                                    Keypress: equal
# 250.4351  250.4351                                    Keypress: equal
# 251.9349  251.9349                                    Keypress: equal
# 253.4346  253.4346                                    Keypress: equal
# 254.9322  254.9322                                    Keypress: equal
# 256.4323  256.4323                                    Keypress: equal
# 257.9346  257.9346                                    Keypress: equal
# 259.4351  259.4351                                    Keypress: equal
# 260.9354  260.9354                                    Keypress: equal
# 262.4346  262.4346                                    Keypress: equal
